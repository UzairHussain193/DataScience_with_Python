# %% [markdown]
# ## Data visualization on IRIS Dataset

# %%
#  importing libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# importing dataset
phool = sns.load_dataset("iris")
phool
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
phool.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
# checking null values
phool.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
# plotting
phool.species.value_counts().plot(kind="bar")
# Out:
# <Axes: >

# %%
sns.countplot(x="species",data=phool)
# Out:
# <Axes: xlabel='species', ylabel='count'>

# %%
sns.countplot(x="sepal_length",hue="species",data=phool)
# Out:
# <Axes: xlabel='sepal_length', ylabel='count'>

# %%
phool.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
plt.scatter(data=phool,x="sepal_length",y="species")

# %%
sns.scatterplot(data=phool,x="sepal_width",y="sepal_length",hue="species")
# Out:
# <Axes: xlabel='sepal_width', ylabel='sepal_length'>

# %%
sns.barplot(data=phool,x="petal_length",y="sepal_width",hue="species")
# Out:
# <Axes: xlabel='petal_length', ylabel='sepal_width'>

# %%
sns.pairplot(phool)

# %%
phool.hist()
# Out:
# array([[<Axes: title={'center': 'sepal_length'}>,
#         <Axes: title={'center': 'sepal_width'}>],
#        [<Axes: title={'center': 'petal_length'}>,
#         <Axes: title={'center': 'petal_width'}>]], dtype=object)

# %%
phool.hist(bins=10,figsize=(10,8),grid=False)
# Out:
# array([[<Axes: title={'center': 'sepal_length'}>,
#         <Axes: title={'center': 'sepal_width'}>],
#        [<Axes: title={'center': 'petal_length'}>,
#         <Axes: title={'center': 'petal_width'}>]], dtype=object)

# %%
sns.boxplot(data=phool,x="sepal_width",y="sepal_length",hue="species")
# Out:
# <Axes: xlabel='sepal_width', ylabel='sepal_length'>

# %%
sns.boxenplot(data=phool,x="sepal_width",y="sepal_length",hue="species")
# Out:
# <Axes: xlabel='sepal_width', ylabel='sepal_length'>

# %%
# grid plot usinf facetgrid
g = sns.FacetGrid(phool,col="species",hue="sepal_width")
g.map(plt.scatter,"sepal_length")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 3
#       1 # grid plot usinf facetgrid
#       2 g = sns.FacetGrid(phool,col="species",hue="sepal_width")
# ----> 3 g.map(plt.scatter,"sepal_length")
#
# File c:\Users\Administrator\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:752, in FacetGrid.map(self, func, *args, **kwargs)
#     749         plot_args = [v.values for v in plot_args]
#     751     # Draw the plot
# --> 752     self._facet_plot(func, ax, plot_args, kwargs)
#     754 # Finalize the annotations and layout
#     755 self._finalize_grid(args[:2])
#
# File c:\Users\Administrator\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:848, in FacetGrid._facet_plot(self, func, ax, plot_args, plot_kwargs)
#     846     plot_args = []
#     847     plot_kwargs["ax"] = ax
# ...

# %%
# grid plot usinf facetgrid

g = sns.FacetGrid(phool,  hue="species",col='petal_length', margin_titles=True,
              palette={1:"black", 0:"red"})
# g = g.map(plt.scatter,"petal_length","petal_width",edgecolor="w").add_legend()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[24], line 2
#       1 # grid plot usinf facetgrid
# ----> 2 g = sns.FacetGrid(phool,  hue="species",col='petal_length', margin_titles=True,
#       3               palette={1:"black", 0:"red"})
#       4 # g = g.map(plt.scatter,"petal_length","petal_width",edgecolor="w").add_legend()
#
# File c:\Users\Administrator\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:385, in FacetGrid.__init__(self, data, row, col, hue, col_wrap, sharex, sharey, height, aspect, palette, row_order, col_order, hue_order, hue_kws, dropna, legend_out, despine, margin_titles, xlim, ylim, subplot_kws, gridspec_kws)
#     382 else:
#     383     hue_names = categorical_order(data[hue], hue_order)
# --> 385 colors = self._get_palette(data, hue, hue_order, palette)
# ...
