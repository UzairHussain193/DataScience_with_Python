# %% [markdown]
# # PANDAS - DAY 3 ( TIPS AND TRICKS )

# %% [markdown]
# ### 01 . How to find the version?

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '1.5.3'

# %%
pd.show_versions()
# Out:
# c:\Users\Administrator\AppData\Local\Programs\Python\Python311\Lib\site-packages\_distutils_hack\__init__.py:33: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# INSTALLED VERSIONS
# ------------------
# commit           : 2e218d10984e9919f0296931d92ea851c6a6faf5
# python           : 3.11.1.final.0
# python-bits      : 64
# OS               : Windows
# OS-release       : 10
# Version          : 10.0.22000
# machine          : AMD64
# processor        : Intel64 Family 6 Model 78 Stepping 3, GenuineIntel
# byteorder        : little
# LC_ALL           : None
# LANG             : None
# LOCALE           : English_United States.1252
#
# pandas           : 1.5.3
# numpy            : 1.24.2
# pytz             : 2022.7.1
# dateutil         : 2.8.2
# setuptools       : 65.5.0
# pip              : 23.1.2
# Cython           : None
# pytest           : None
# hypothesis       : None
# sphinx           : None
# blosc            : None
# ...

# %% [markdown]
# ### 02- Making a Data Frame

# %%
df=pd.DataFrame({'Name ':["Uzair","Abbas","Lahad","Razi","Bilal"],'Age ': [20,19,21,22,19]})

# %%
df
# Out:
#    Name   Age
# 0  Uzair    20
# 1  Abbas    19
# 2  Lahad    21
# 3   Razi    22
# 4  Bilal    19

# %%
df.head()
# Out:
#    Name   Age
# 0  Uzair    20
# 1  Abbas    19
# 2  Lahad    21
# 3   Razi    22
# 4  Bilal    19

# %%
df.tail()
# Out:
#    Name   Age
# 0  Uzair    20
# 1  Abbas    19
# 2  Lahad    21
# 3   Razi    22
# 4  Bilal    19

# %%
df
# Out:
#    Name   Age
# 0  Uzair    20
# 1  Abbas    19
# 2  Lahad    21
# 3   Razi    22
# 4  Bilal    19

# %%
# numpy array to create dataframe
import numpy as np
arr=np.array([['Uzair',20],['Abbas',19],['Lahad',21],['Razi',22],['Bilal',19]])
# arr
df=pd.DataFrame(arr,columns=['Name','Age'])
df
# Out:
#     Name Age
# 0  Uzair  20
# 1  Abbas  19
# 2  Lahad  21
# 3   Razi  22
# 4  Bilal  19

# %%
# numpy array data frame
pd.DataFrame(np.random.rand(5,2))
pd.DataFrame(np.random.rand(5,2), columns=list("AB"))
# Out:
#           A         B
# 0  0.594315  0.381209
# 1  0.331848  0.157232
# 2  0.712960  0.184831
# 3  0.237691  0.848901
# 4  0.326512  0.925356

# %%
pd.DataFrame(np.random.rand(50,20))
# Out:
#           0         1         2         3         4         5         6   \
# 0   0.476970  0.971715  0.171322  0.096842  0.170747  0.128484  0.151573
# 1   0.085837  0.784731  0.650310  0.509409  0.328697  0.939738  0.118383
# 2   0.945632  0.158445  0.856832  0.562940  0.138172  0.137193  0.675871
# 3   0.914025  0.689922  0.352097  0.092385  0.162663  0.137718  0.544724
# 4   0.021880  0.842420  0.926421  0.076815  0.276106  0.995143  0.515722
# 5   0.014206  0.303479  0.708456  0.956972  0.608002  0.567955  0.081463
# 6   0.930111  0.197729  0.017197  0.674976  0.089906  0.492142  0.681200
# 7   0.027903  0.615354  0.542529  0.714584  0.340587  0.596382  0.302708
# 8   0.162358  0.166176  0.750051  0.742218  0.626747  0.350505  0.916193
# 9   0.529970  0.669565  0.970183  0.656581  0.755517  0.988743  0.919770
# 10  0.375956  0.327146  0.925454  0.158738  0.052713  0.602231  0.121930
# 11  0.104387  0.018290  0.213593  0.201032  0.062374  0.902930  0.411929
# ...

# %%
df
# Out:
#     Name Age
# 0  Uzair  20
# 1  Abbas  19
# 2  Lahad  21
# 3   Razi  22
# 4  Bilal  19

# %%
# how to rename column names
df=pd.DataFrame({'A col ':[1,2,3,4,5],'B col ': [20,19,18,17,16]})

# %%
df.rename(columns={'A col': 'a col','B col':'b col'}, inplace=True)

# %%
df
# Out:
#    A col   B col
# 0       1      20
# 1       2      19
# 2       3      18
# 3       4      17
# 4       5      16

# %%
df.columns=['aa_col','bb_col']

# %%
df
# Out:
#    aa_col  bb_col
# 0       1      20
# 1       2      19
# 2       3      18
# 3       4      17
# 4       5      16

# %%
# to replace any character, string, lateral
df.columns=df.columns.str.replace('_',' ')

# %%
df
# Out:
#    aa col  bb col
# 0       1      20
# 1       2      19
# 2       3      18
# 3       4      17
# 4       5      16
