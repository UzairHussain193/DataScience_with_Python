# %% [markdown]
# # PANDAS - DAY 3 ( TIPS AND TRICKS )

# %% [markdown]
# ## Table of Contents:
#
# [1. how-to-find-the-version](#01--how-to-find-the-version)\
# [2. making-a-data-frame](#02--making-a-data-frame)\
# [3. using-numpy-to-create-dataframe](#3--using-numpy-to-create-dataframe)\
# [4. sing-template-data](#4-using-template-data)\
# [5. using-your-own-data](#5-using-your-own-data)\
# [6. reverse-row-order](#6-reverse-row-order)\
# [7. reverse-colun-order](#7--reverse-colun-order)\
# [8. select-a-cloumn-by-a-data-type](#8--select-a-cloumn-by-a-data-type)\
# [9. convert-numbers-into-strings](#9--convert-numbers-into-strings)\
# [10. reduce-dataframe-size](#10--reduce-dataframe-size)\
# [11. copy-data-from-clipboard](#11--copy-data-from-clipboard)\
# [12. split-data-sets-in-two-frames](#12---split-data-sets-in-two-frames)\
# [13. joining-dataset-into-one-dataframe](#13---joining-dataset-into-one-dataframe)\
# [14. filtering-a-data-set](#14---filtering-a-data-set)\
# [15. filtering-by-large-categories](#15-filtering-by-large-categories)\
# [16. splitting-a-string-into-multiple-cloumns](#16---splitting-a-string-into-multiple-cloumns)\
# [17. aggregate-by-multiple-groupsfunctions](#17---aggregate-by-multiple-groupsfunctions)\
# [18. select-specific-rows-and-columns](#18---select-specific-rows-and-columns)

# %% [markdown]
# ### 01 . How to find the version?

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '1.5.3'

# %%
pd.show_versions()
# Out:
# c:\Users\Administrator\AppData\Local\Programs\Python\Python311\Lib\site-packages\_distutils_hack\__init__.py:33: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# INSTALLED VERSIONS
# ------------------
# commit           : 2e218d10984e9919f0296931d92ea851c6a6faf5
# python           : 3.11.1.final.0
# python-bits      : 64
# OS               : Windows
# OS-release       : 10
# Version          : 10.0.22000
# machine          : AMD64
# processor        : Intel64 Family 6 Model 78 Stepping 3, GenuineIntel
# byteorder        : little
# LC_ALL           : None
# LANG             : None
# LOCALE           : English_United States.1252
#
# pandas           : 1.5.3
# numpy            : 1.24.2
# pytz             : 2022.7.1
# dateutil         : 2.8.2
# setuptools       : 65.5.0
# pip              : 23.1.2
# Cython           : None
# pytest           : None
# hypothesis       : None
# sphinx           : None
# blosc            : None
# feather          : None
# xlsxwriter       : None
# lxml.etree       : None
# html5lib         : None
# pymysql          : None
# psycopg2         : None
# jinja2           : 3.1.2
# IPython          : 8.13.2
# pandas_datareader: None
# bs4              : 4.11.2
# bottleneck       : None
# brotli           : None
# fastparquet      : None
# fsspec           : None
# gcsfs            : None
# matplotlib       : 3.7.1
# numba            : None
# numexpr          : None
# odfpy            : None
# openpyxl         : 3.1.2
# pandas_gbq       : None
# pyarrow          : None
# pyreadstat       : None
# pyxlsb           : None
# s3fs             : None
# scipy            : None
# snappy           : None
# sqlalchemy       : None
# tables           : None
# tabulate         : None
# xarray           : None
# xlrd             : None
# xlwt             : None
# zstandard        : None
# tzdata           : None

# %% [markdown]
# ### 02- Making a Data Frame

# %%
df=pd.DataFrame({'Name ':["Uzair","Abbas","Lahad","Razi","Bilal"],'Age ': [20,19,21,22,19]})

# %%
df
# Out:
#    Name   Age
# 0  Uzair    20
# 1  Abbas    19
# 2  Lahad    21
# 3   Razi    22
# 4  Bilal    19

# %%
df.head()
# Out:
#    Name   Age
# 0  Uzair    20
# 1  Abbas    19
# 2  Lahad    21
# 3   Razi    22
# 4  Bilal    19

# %%
df.tail()
# Out:
#    Name   Age
# 0  Uzair    20
# 1  Abbas    19
# 2  Lahad    21
# 3   Razi    22
# 4  Bilal    19

# %%
df
# Out:
#    Name   Age
# 0  Uzair    20
# 1  Abbas    19
# 2  Lahad    21
# 3   Razi    22
# 4  Bilal    19

# %% [markdown]
# # 3- using numpy to create dataframe

# %%
# numpy array to create dataframe
import numpy as np
arr=np.array([['Uzair',20],['Abbas',19],['Lahad',21],['Razi',22],['Bilal',19]])
# arr
df=pd.DataFrame(arr,columns=['Name','Age'])
df
# Out:
#     Name Age
# 0  Uzair  20
# 1  Abbas  19
# 2  Lahad  21
# 3   Razi  22
# 4  Bilal  19

# %%
# numpy array data frame
pd.DataFrame(np.random.rand(5,2))
pd.DataFrame(np.random.rand(5,2), columns=list("AB"))
# Out:
#           A         B
# 0  0.617030  0.832101
# 1  0.779966  0.964267
# 2  0.530838  0.178937
# 3  0.905138  0.778472
# 4  0.334430  0.911420

# %%
pd.DataFrame(np.random.rand(50,20))
# Out:
#           0         1         2         3         4         5         6   \
# 0   0.525005  0.856645  0.332990  0.430700  0.324347  0.025473  0.043003
# 1   0.534518  0.784893  0.292860  0.061573  0.453429  0.259122  0.622257
# 2   0.409451  0.700769  0.279786  0.255558  0.535753  0.666416  0.779877
# 3   0.531736  0.671678  0.732474  0.247746  0.064553  0.169975  0.183520
# 4   0.586219  0.043701  0.384159  0.643919  0.982143  0.591570  0.139610
# 5   0.465231  0.992202  0.439090  0.423798  0.075402  0.082098  0.195137
# 6   0.030587  0.869262  0.186653  0.168487  0.659033  0.916086  0.856839
# 7   0.310810  0.993894  0.655867  0.885459  0.664502  0.002596  0.444756
# 8   0.051074  0.871498  0.859824  0.865034  0.269499  0.634829  0.702135
# 9   0.347505  0.246098  0.766756  0.191472  0.090772  0.881829  0.644404
# 10  0.057147  0.614785  0.544784  0.138068  0.915105  0.878686  0.569458
# 11  0.896083  0.545114  0.954102  0.662628  0.964958  0.550072  0.060674
# 12  0.823625  0.302623  0.093122  0.627116  0.221128  0.290180  0.283190
# 13  0.836431  0.215984  0.755202  0.485836  0.832135  0.861311  0.305188
# 14  0.479841  0.090206  0.758432  0.067678  0.180230  0.262296  0.223682
# 15  0.947302  0.904887  0.616517  0.675023  0.944422  0.531900  0.468233
# 16  0.593973  0.461517  0.704528  0.034406  0.954553  0.726507  0.781977
# 17  0.104789  0.365287  0.131238  0.521309  0.853595  0.408501  0.476827
# 18  0.721570  0.130651  0.205118  0.600701  0.552772  0.488045  0.190784
# 19  0.410317  0.317697  0.426084  0.639899  0.684445  0.378255  0.032149
# 20  0.530370  0.289232  0.401493  0.938006  0.626673  0.667030  0.272357
# 21  0.273423  0.131711  0.497749  0.351221  0.078425  0.134396  0.908524
# 22  0.361645  0.621030  0.241956  0.609562  0.520014  0.706864  0.523144
# 23  0.651319  0.745647  0.491330  0.377603  0.094675  0.340194  0.571238
# 24  0.719020  0.854201  0.204718  0.889619  0.582812  0.734596  0.129181
# 25  0.168964  0.912458  0.534459  0.888520  0.457244  0.856832  0.165203
# 26  0.292535  0.510814  0.102288  0.942108  0.401298  0.746240  0.243541
# 27  0.239045  0.300540  0.401322  0.361352  0.781306  0.977386  0.006498
# 28  0.403435  0.694323  0.218513  0.820628  0.653173  0.662768  0.438707
# 29  0.434641  0.876832  0.750904  0.378090  0.692632  0.811290  0.654366
# 30  0.406295  0.580885  0.757485  0.973964  0.051831  0.663258  0.990104
# 31  0.024631  0.465394  0.170408  0.333743  0.310290  0.762396  0.696979
# 32  0.799882  0.498552  0.944398  0.115050  0.843344  0.913674  0.633507
# 33  0.083848  0.877484  0.606173  0.948812  0.226208  0.987283  0.772130
# 34  0.373738  0.743626  0.656400  0.706085  0.899945  0.546324  0.835039
# 35  0.842947  0.169208  0.229541  0.983084  0.836996  0.889329  0.233394
# 36  0.310213  0.038188  0.317352  0.881580  0.403253  0.058878  0.772098
# 37  0.975094  0.101913  0.081070  0.351245  0.819265  0.466671  0.936709
# 38  0.955629  0.538937  0.000583  0.250423  0.166009  0.283513  0.928649
# 39  0.913987  0.627841  0.787894  0.661799  0.895702  0.004213  0.305239
# 40  0.713527  0.470443  0.617399  0.057970  0.683684  0.289758  0.350539
# 41  0.682442  0.137502  0.308848  0.512577  0.285569  0.226604  0.655948
# 42  0.183836  0.229774  0.385939  0.536734  0.347882  0.645617  0.134434
# 43  0.285926  0.264529  0.750058  0.580734  0.578233  0.046531  0.028104
# 44  0.937922  0.985499  0.031732  0.896830  0.132700  0.492512  0.699075
# 45  0.606027  0.485698  0.181607  0.944668  0.397191  0.152882  0.893666
# 46  0.548431  0.326777  0.731625  0.878323  0.603194  0.801298  0.174264
# 47  0.257803  0.323326  0.512140  0.160684  0.265978  0.909065  0.344398
# 48  0.593938  0.088960  0.805370  0.183959  0.378970  0.547812  0.808164
# 49  0.625586  0.408699  0.530487  0.424970  0.388097  0.852290  0.841567
#
#           7         8         9         10        11        12        13  \
# 0   0.609331  0.737519  0.248640  0.800729  0.560255  0.427008  0.427211
# 1   0.810349  0.100784  0.706756  0.363643  0.852612  0.626142  0.235058
# 2   0.054265  0.119618  0.808948  0.300279  0.991915  0.452350  0.910256
# 3   0.640148  0.997737  0.765617  0.390847  0.044080  0.472044  0.702942
# 4   0.451497  0.394496  0.684717  0.709581  0.948022  0.947359  0.612960
# 5   0.118909  0.390057  0.154296  0.375281  0.065961  0.719126  0.071695
# 6   0.987716  0.379475  0.217094  0.178642  0.254878  0.978453  0.712541
# 7   0.391428  0.515735  0.960897  0.889257  0.960810  0.292429  0.446459
# 8   0.564129  0.415196  0.862840  0.488092  0.574848  0.994668  0.348287
# 9   0.044775  0.324795  0.408897  0.345845  0.003842  0.349940  0.928586
# 10  0.750567  0.096584  0.680123  0.417229  0.369484  0.040189  0.279938
# 11  0.905344  0.103769  0.070188  0.470117  0.887292  0.256263  0.090375
# 12  0.976368  0.706354  0.010936  0.416650  0.135548  0.541854  0.397144
# 13  0.638159  0.130141  0.737421  0.403574  0.541129  0.870627  0.452367
# 14  0.273049  0.285500  0.356248  0.863763  0.887349  0.062482  0.172505
# 15  0.920894  0.921178  0.063204  0.582222  0.140558  0.943008  0.485267
# 16  0.511055  0.266299  0.669084  0.209171  0.437155  0.291825  0.999173
# 17  0.656587  0.502545  0.710442  0.103893  0.414285  0.349627  0.233910
# 18  0.231819  0.148739  0.583807  0.568853  0.648829  0.730650  0.056881
# 19  0.853503  0.543659  0.368328  0.975661  0.189653  0.312992  0.479283
# 20  0.848764  0.419830  0.055225  0.599274  0.272957  0.275196  0.727979
# 21  0.754358  0.381661  0.288878  0.401713  0.133052  0.273213  0.499867
# 22  0.316942  0.807670  0.718754  0.195444  0.226075  0.938852  0.400776
# 23  0.837090  0.103687  0.959372  0.220433  0.659731  0.841404  0.065692
# 24  0.742906  0.641397  0.572204  0.219018  0.678417  0.664070  0.639281
# 25  0.884198  0.803045  0.374982  0.141223  0.388758  0.980444  0.952681
# 26  0.349377  0.130635  0.825098  0.108619  0.935550  0.444247  0.907642
# 27  0.716573  0.153600  0.400332  0.895436  0.007744  0.028761  0.192560
# 28  0.052808  0.133203  0.936518  0.300542  0.377337  0.332575  0.463167
# 29  0.383207  0.938889  0.340190  0.144399  0.487046  0.439026  0.570201
# 30  0.092313  0.647007  0.588965  0.873530  0.989821  0.913754  0.589099
# 31  0.778908  0.313246  0.763343  0.766189  0.036641  0.544329  0.260674
# 32  0.951199  0.361365  0.263931  0.081301  0.941872  0.692303  0.472414
# 33  0.024910  0.512029  0.572314  0.792196  0.594434  0.193293  0.603988
# 34  0.175530  0.735755  0.986652  0.898724  0.087701  0.349677  0.915929
# 35  0.986844  0.293008  0.193786  0.916413  0.151900  0.829338  0.882861
# 36  0.053368  0.063658  0.456019  0.262082  0.783854  0.133646  0.984284
# 37  0.512378  0.035879  0.924974  0.856574  0.750524  0.830797  0.492889
# 38  0.194171  0.098541  0.166797  0.279495  0.460862  0.321225  0.023203
# 39  0.366080  0.990184  0.119112  0.000877  0.826734  0.658385  0.153229
# 40  0.905699  0.514320  0.012784  0.588427  0.233571  0.109449  0.019248
# 41  0.076839  0.118487  0.626638  0.085064  0.567173  0.105850  0.329493
# 42  0.145907  0.706245  0.956619  0.888202  0.701624  0.193009  0.805306
# 43  0.647620  0.054760  0.564583  0.635595  0.572693  0.285313  0.646446
# 44  0.451994  0.475475  0.057640  0.320219  0.350027  0.878905  0.121717
# 45  0.101881  0.843306  0.935361  0.180484  0.024506  0.758025  0.006004
# 46  0.852238  0.169794  0.980382  0.072387  0.393801  0.011245  0.040979
# 47  0.688987  0.786989  0.291130  0.112571  0.412309  0.516057  0.343122
# 48  0.656682  0.180894  0.232059  0.802206  0.643919  0.248025  0.456373
# 49  0.150497  0.195782  0.311240  0.084168  0.567204  0.553043  0.848530
#
#           14        15        16        17        18        19
# 0   0.440642  0.679850  0.697500  0.150987  0.918898  0.825560
# 1   0.208469  0.580981  0.406559  0.921726  0.820411  0.194188
# 2   0.116212  0.935100  0.977741  0.020904  0.720865  0.499166
# 3   0.481810  0.356832  0.969587  0.209134  0.458164  0.938737
# 4   0.847228  0.593060  0.368875  0.723245  0.540999  0.376485
# 5   0.832810  0.129639  0.134581  0.116741  0.261969  0.775469
# 6   0.495574  0.695755  0.541047  0.861887  0.026701  0.031172
# 7   0.832340  0.715019  0.666172  0.321553  0.227393  0.047375
# 8   0.369486  0.732605  0.310409  0.129570  0.290374  0.921837
# 9   0.525634  0.258747  0.258151  0.649813  0.719151  0.230790
# 10  0.632969  0.688361  0.547127  0.884320  0.348115  0.965446
# 11  0.383630  0.108374  0.117591  0.167366  0.538390  0.649338
# 12  0.793848  0.416546  0.871581  0.137075  0.096961  0.271877
# 13  0.264847  0.309367  0.172887  0.668678  0.680915  0.845688
# 14  0.663371  0.761322  0.979949  0.993038  0.315198  0.445176
# 15  0.274132  0.040586  0.472657  0.148263  0.323773  0.242098
# 16  0.686558  0.298768  0.893020  0.987232  0.944383  0.797319
# 17  0.961242  0.527955  0.961158  0.403162  0.737715  0.828416
# 18  0.783867  0.919812  0.176036  0.003340  0.822355  0.474537
# 19  0.240491  0.591226  0.321188  0.054336  0.353851  0.337336
# 20  0.178077  0.952773  0.570429  0.640282  0.986033  0.539452
# 21  0.251681  0.562388  0.070585  0.747373  0.907152  0.462599
# 22  0.457987  0.048144  0.304683  0.690701  0.912185  0.300038
# 23  0.886106  0.128467  0.620627  0.088072  0.271884  0.844360
# 24  0.339758  0.293922  0.039284  0.464596  0.781942  0.016853
# 25  0.147475  0.788953  0.864464  0.373187  0.617524  0.071994
# 26  0.891624  0.228813  0.281821  0.057174  0.110401  0.321648
# 27  0.455201  0.441420  0.269428  0.002511  0.604606  0.960703
# 28  0.795147  0.785608  0.820447  0.702380  0.542610  0.098720
# 29  0.063169  0.118891  0.272747  0.868084  0.200647  0.639430
# 30  0.851930  0.882134  0.177123  0.713339  0.900242  0.808679
# 31  0.589664  0.247271  0.903510  0.230293  0.771449  0.209170
# 32  0.368714  0.832590  0.135168  0.279421  0.369093  0.343473
# 33  0.431311  0.832167  0.436293  0.345545  0.056030  0.281005
# 34  0.576895  0.820880  0.803533  0.422167  0.215314  0.198235
# 35  0.462541  0.329166  0.153689  0.019534  0.986871  0.225698
# 36  0.499033  0.560604  0.103003  0.153953  0.418967  0.500833
# 37  0.124409  0.151454  0.584581  0.399464  0.623411  0.948560
# 38  0.195340  0.893854  0.179148  0.565915  0.488220  0.653370
# 39  0.185754  0.429938  0.452805  0.825390  0.713975  0.664393
# 40  0.896379  0.198597  0.262830  0.308795  0.923358  0.278859
# 41  0.986624  0.462519  0.278547  0.926909  0.548729  0.227111
# 42  0.454983  0.092103  0.691952  0.223362  0.118851  0.838963
# 43  0.377380  0.861473  0.267138  0.645448  0.526862  0.732666
# 44  0.216020  0.515535  0.539260  0.544642  0.229013  0.780377
# 45  0.231369  0.586132  0.229040  0.642817  0.156249  0.876708
# 46  0.235135  0.229838  0.699419  0.281002  0.428696  0.601163
# 47  0.043415  0.006954  0.499889  0.954193  0.306196  0.094574
# 48  0.453406  0.309618  0.565662  0.927663  0.060854  0.289150
# 49  0.508385  0.373662  0.554687  0.342816  0.940022  0.860642

# %%
df
# Out:
#     Name Age
# 0  Uzair  20
# 1  Abbas  19
# 2  Lahad  21
# 3   Razi  22
# 4  Bilal  19

# %%
# how to rename column names
df=pd.DataFrame({'A col ':[1,2,3,4,5],'B col ': [20,19,18,17,16]})

# %%
df.rename(columns={'A col': 'a col','B col':'b col'}, inplace=True)

# %%
df
# Out:
#    A col   B col
# 0       1      20
# 1       2      19
# 2       3      18
# 3       4      17
# 4       5      16

# %%
df.columns=['aa_col','bb_col']

# %%
df
# Out:
#    aa_col  bb_col
# 0       1      20
# 1       2      19
# 2       3      18
# 3       4      17
# 4       5      16

# %%
# to replace any character, string, lateral
df.columns=df.columns.str.replace('_',' ')

# %%
df
# Out:
#    aa col  bb col
# 0       1      20
# 1       2      19
# 2       3      18
# 3       4      17
# 4       5      16

# %%
# adding prefix
df.add_prefix('UHS_')
# Out:
#    UHS_aa col  UHS_bb col
# 0           1          20
# 1           2          19
# 2           3          18
# 3           4          17
# 4           5          16

# %%
# adding suffix
df.add_suffix('_UHS')
# Out:
#    aa col_UHS  bb col_UHS
# 0           1          20
# 1           2          19
# 2           3          18
# 3           4          17
# 4           5          16

# %% [markdown]
# # 4 using template data

# %%
import pandas as pd
import numpy as np
import seaborn as sns

kashti = sns.load_dataset('titanic')
kashti.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
#  summary
kashti.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
# cloumns names
kashti.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
# saving a template dataset

kashti.to_csv('kashti.csv')

# %%
# saving to excel
kashti.to_excel('kashti.xlsx')

# %%
# viewing csv file
kashti=pd.read_csv('kashti.csv')
kashti
# Out:
#      Unnamed: 0  survived  pclass     sex   age  sibsp  parch     fare  \
# 0             0         0       3    male  22.0      1      0   7.2500
# 1             1         1       1  female  38.0      1      0  71.2833
# 2             2         1       3  female  26.0      0      0   7.9250
# 3             3         1       1  female  35.0      1      0  53.1000
# 4             4         0       3    male  35.0      0      0   8.0500
# ..          ...       ...     ...     ...   ...    ...    ...      ...
# 886         886         0       2    male  27.0      0      0  13.0000
# 887         887         1       1  female  19.0      0      0  30.0000
# 888         888         0       3  female   NaN      1      2  23.4500
# 889         889         1       1    male  26.0      0      0  30.0000
# 890         890         0       3    male  32.0      0      0   7.7500
#
#     embarked   class    who  adult_male deck  embark_town alive  alone
# 0          S   Third    man        True  NaN  Southampton    no  False
# 1          C   First  woman       False    C    Cherbourg   yes  False
# 2          S   Third  woman       False  NaN  Southampton   yes   True
# 3          S   First  woman       False    C  Southampton   yes  False
# 4          S   Third    man        True  NaN  Southampton    no   True
# ..       ...     ...    ...         ...  ...          ...   ...    ...
# 886        S  Second    man        True  NaN  Southampton    no   True
# 887        S   First  woman       False    B  Southampton   yes   True
# 888        S   Third  woman       False  NaN  Southampton    no  False
# 889        C   First    man        True    C    Cherbourg   yes   True
# 890        Q   Third    man        True  NaN   Queenstown    no   True
#
# [891 rows x 16 columns]

# %%
# reading excel file
kashti=pd.read_excel('kashti.xlsx')
kashti
# Out:
#      Unnamed: 0  survived  pclass     sex   age  sibsp  parch     fare  \
# 0             0         0       3    male  22.0      1      0   7.2500
# 1             1         1       1  female  38.0      1      0  71.2833
# 2             2         1       3  female  26.0      0      0   7.9250
# 3             3         1       1  female  35.0      1      0  53.1000
# 4             4         0       3    male  35.0      0      0   8.0500
# ..          ...       ...     ...     ...   ...    ...    ...      ...
# 886         886         0       2    male  27.0      0      0  13.0000
# 887         887         1       1  female  19.0      0      0  30.0000
# 888         888         0       3  female   NaN      1      2  23.4500
# 889         889         1       1    male  26.0      0      0  30.0000
# 890         890         0       3    male  32.0      0      0   7.7500
#
#     embarked   class    who  adult_male deck  embark_town alive  alone
# 0          S   Third    man        True  NaN  Southampton    no  False
# 1          C   First  woman       False    C    Cherbourg   yes  False
# 2          S   Third  woman       False  NaN  Southampton   yes   True
# 3          S   First  woman       False    C  Southampton   yes  False
# 4          S   Third    man        True  NaN  Southampton    no   True
# ..       ...     ...    ...         ...  ...          ...   ...    ...
# 886        S  Second    man        True  NaN  Southampton    no   True
# 887        S   First  woman       False    B  Southampton   yes   True
# 888        S   Third  woman       False  NaN  Southampton    no  False
# 889        C   First    man        True    C    Cherbourg   yes   True
# 890        Q   Third    man        True  NaN   Queenstown    no   True
#
# [891 rows x 16 columns]

# %%
# to text file
kashti.to_csv('kashti.txt',sep='\t')

# %%
#  reading text file
kashti=pd.read_csv('kashti.txt',sep='\t')
kashti
# Out:
#      Unnamed: 0.1  Unnamed: 0  survived  pclass     sex   age  sibsp  parch  \
# 0               0           0         0       3    male  22.0      1      0
# 1               1           1         1       1  female  38.0      1      0
# 2               2           2         1       3  female  26.0      0      0
# 3               3           3         1       1  female  35.0      1      0
# 4               4           4         0       3    male  35.0      0      0
# ..            ...         ...       ...     ...     ...   ...    ...    ...
# 886           886         886         0       2    male  27.0      0      0
# 887           887         887         1       1  female  19.0      0      0
# 888           888         888         0       3  female   NaN      1      2
# 889           889         889         1       1    male  26.0      0      0
# 890           890         890         0       3    male  32.0      0      0
#
#         fare embarked   class    who  adult_male deck  embark_town alive  \
# 0     7.2500        S   Third    man        True  NaN  Southampton    no
# 1    71.2833        C   First  woman       False    C    Cherbourg   yes
# 2     7.9250        S   Third  woman       False  NaN  Southampton   yes
# 3    53.1000        S   First  woman       False    C  Southampton   yes
# 4     8.0500        S   Third    man        True  NaN  Southampton    no
# ..       ...      ...     ...    ...         ...  ...          ...   ...
# 886  13.0000        S  Second    man        True  NaN  Southampton    no
# 887  30.0000        S   First  woman       False    B  Southampton   yes
# 888  23.4500        S   Third  woman       False  NaN  Southampton    no
# 889  30.0000        C   First    man        True    C    Cherbourg   yes
# 890   7.7500        Q   Third    man        True  NaN   Queenstown    no
#
#      alone
# 0    False
# 1    False
# 2     True
# 3    False
# 4     True
# ..     ...
# 886   True
# 887   True
# 888  False
# 889   True
# 890   True
#
# [891 rows x 17 columns]

# %% [markdown]
# # 5 using your own data

# %%
import pandas as pd
df = pd.read_csv('database.csv')
df
# Out:
#              Date      Time  Latitude  Longitude        Type   Depth  \
# 0      01/02/1965  13:44:18   19.2460   145.6160  Earthquake  131.60
# 1      01/04/1965  11:29:49    1.8630   127.3520  Earthquake   80.00
# 2      01/05/1965  18:05:58  -20.5790  -173.9720  Earthquake   20.00
# 3      01/08/1965  18:49:43  -59.0760   -23.5570  Earthquake   15.00
# 4      01/09/1965  13:32:50   11.9380   126.4270  Earthquake   15.00
# ...           ...       ...       ...        ...         ...     ...
# 23407  12/28/2016  08:22:12   38.3917  -118.8941  Earthquake   12.30
# 23408  12/28/2016  09:13:47   38.3777  -118.8957  Earthquake    8.80
# 23409  12/28/2016  12:38:51   36.9179   140.4262  Earthquake   10.00
# 23410  12/29/2016  22:30:19   -9.0283   118.6639  Earthquake   79.00
# 23411  12/30/2016  20:08:28   37.3973   141.4103  Earthquake   11.94
#
#        Depth Error  Depth Seismic Stations  Magnitude Magnitude Type  ...  \
# 0              NaN                     NaN        6.0             MW  ...
# 1              NaN                     NaN        5.8             MW  ...
# 2              NaN                     NaN        6.2             MW  ...
# 3              NaN                     NaN        5.8             MW  ...
# 4              NaN                     NaN        5.8             MW  ...
# ...            ...                     ...        ...            ...  ...
# 23407          1.2                    40.0        5.6             ML  ...
# 23408          2.0                    33.0        5.5             ML  ...
# 23409          1.8                     NaN        5.9            MWW  ...
# 23410          1.8                     NaN        6.3            MWW  ...
# 23411          2.2                     NaN        5.5             MB  ...
#
#        Magnitude Seismic Stations  Azimuthal Gap  Horizontal Distance  \
# 0                             NaN            NaN                  NaN
# 1                             NaN            NaN                  NaN
# 2                             NaN            NaN                  NaN
# 3                             NaN            NaN                  NaN
# 4                             NaN            NaN                  NaN
# ...                           ...            ...                  ...
# 23407                        18.0          42.47                0.120
# 23408                        18.0          48.58                0.129
# 23409                         NaN          91.00                0.992
# 23410                         NaN          26.00                3.553
# 23411                       428.0          97.00                0.681
#
#        Horizontal Error  Root Mean Square            ID  Source  \
# 0                   NaN               NaN  ISCGEM860706  ISCGEM
# 1                   NaN               NaN  ISCGEM860737  ISCGEM
# 2                   NaN               NaN  ISCGEM860762  ISCGEM
# 3                   NaN               NaN  ISCGEM860856  ISCGEM
# 4                   NaN               NaN  ISCGEM860890  ISCGEM
# ...                 ...               ...           ...     ...
# 23407               NaN            0.1898    NN00570710      NN
# 23408               NaN            0.2187    NN00570744      NN
# 23409               4.8            1.5200    US10007NAF      US
# 23410               6.0            1.4300    US10007NL0      US
# 23411               4.5            0.9100    US10007NTD      US
#
#       Location Source Magnitude Source     Status
# 0              ISCGEM           ISCGEM  Automatic
# 1              ISCGEM           ISCGEM  Automatic
# 2              ISCGEM           ISCGEM  Automatic
# 3              ISCGEM           ISCGEM  Automatic
# 4              ISCGEM           ISCGEM  Automatic
# ...               ...              ...        ...
# 23407              NN               NN   Reviewed
# 23408              NN               NN   Reviewed
# 23409              US               US   Reviewed
# 23410              US               US   Reviewed
# 23411              US               US   Reviewed
#
# [23412 rows x 21 columns]

# %%
df.head()
# Out:
#          Date      Time  Latitude  Longitude        Type  Depth  Depth Error  \
# 0  01/02/1965  13:44:18    19.246    145.616  Earthquake  131.6          NaN
# 1  01/04/1965  11:29:49     1.863    127.352  Earthquake   80.0          NaN
# 2  01/05/1965  18:05:58   -20.579   -173.972  Earthquake   20.0          NaN
# 3  01/08/1965  18:49:43   -59.076    -23.557  Earthquake   15.0          NaN
# 4  01/09/1965  13:32:50    11.938    126.427  Earthquake   15.0          NaN
#
#    Depth Seismic Stations  Magnitude Magnitude Type  ...  \
# 0                     NaN        6.0             MW  ...
# 1                     NaN        5.8             MW  ...
# 2                     NaN        6.2             MW  ...
# 3                     NaN        5.8             MW  ...
# 4                     NaN        5.8             MW  ...
#
#    Magnitude Seismic Stations  Azimuthal Gap  Horizontal Distance  \
# 0                         NaN            NaN                  NaN
# 1                         NaN            NaN                  NaN
# 2                         NaN            NaN                  NaN
# 3                         NaN            NaN                  NaN
# 4                         NaN            NaN                  NaN
#
#    Horizontal Error  Root Mean Square            ID  Source Location Source  \
# 0               NaN               NaN  ISCGEM860706  ISCGEM          ISCGEM
# 1               NaN               NaN  ISCGEM860737  ISCGEM          ISCGEM
# 2               NaN               NaN  ISCGEM860762  ISCGEM          ISCGEM
# 3               NaN               NaN  ISCGEM860856  ISCGEM          ISCGEM
# 4               NaN               NaN  ISCGEM860890  ISCGEM          ISCGEM
#
#   Magnitude Source     Status
# 0           ISCGEM  Automatic
# 1           ISCGEM  Automatic
# 2           ISCGEM  Automatic
# 3           ISCGEM  Automatic
# 4           ISCGEM  Automatic
#
# [5 rows x 21 columns]

# %% [markdown]
# # 6 reverse row order

# %%
import pandas as pd
import seaborn as sns

df=sns.load_dataset('titanic')
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True

# %%
# to check in descending order
df.loc[::-1].head()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 890         0       3    male  32.0      0      0   7.75        Q   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 887         1       1  female  19.0      0      0  30.00        S   First
# 886         0       2    male  27.0      0      0  13.00        S  Second
#
#        who  adult_male deck  embark_town alive  alone
# 890    man        True  NaN   Queenstown    no   True
# 889    man        True    C    Cherbourg   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 887  woman       False    B  Southampton   yes   True
# 886    man        True  NaN  Southampton    no   True

# %%
df.loc[::-1].reset_index(drop=True).head()
# Out:
#    survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 0         0       3    male  32.0      0      0   7.75        Q   Third
# 1         1       1    male  26.0      0      0  30.00        C   First
# 2         0       3  female   NaN      1      2  23.45        S   Third
# 3         1       1  female  19.0      0      0  30.00        S   First
# 4         0       2    male  27.0      0      0  13.00        S  Second
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN   Queenstown    no   True
# 1    man        True    C    Cherbourg   yes   True
# 2  woman       False  NaN  Southampton    no  False
# 3  woman       False    B  Southampton   yes   True
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# # 7- reverse colun order

# %%
df.loc[:,::-1].head()
# Out:
#    alone alive  embark_town deck  adult_male    who  class embarked     fare  \
# 0  False    no  Southampton  NaN        True    man  Third        S   7.2500
# 1  False   yes    Cherbourg    C       False  woman  First        C  71.2833
# 2   True   yes  Southampton  NaN       False  woman  Third        S   7.9250
# 3  False   yes  Southampton    C       False  woman  First        S  53.1000
# 4   True    no  Southampton  NaN        True    man  Third        S   8.0500
#
#    parch  sibsp   age     sex  pclass  survived
# 0      0      1  22.0    male       3         0
# 1      0      1  38.0  female       1         1
# 2      0      0  26.0  female       3         1
# 3      0      1  35.0  female       1         1
# 4      0      0  35.0    male       3         0

# %% [markdown]
# # 8- select a cloumn by a data type

# %%
df.dtypes
# Out:
# survived          int64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %%
# only select those having numeric datatype

df.select_dtypes(include=['number']).head()
# Out:
#    survived  pclass   age  sibsp  parch     fare
# 0         0       3  22.0      1      0   7.2500
# 1         1       1  38.0      1      0  71.2833
# 2         1       3  26.0      0      0   7.9250
# 3         1       1  35.0      1      0  53.1000
# 4         0       3  35.0      0      0   8.0500

# %%
#  those with float
df.select_dtypes(include=['float']).head()
# Out:
#     age     fare
# 0  22.0   7.2500
# 1  38.0  71.2833
# 2  26.0   7.9250
# 3  35.0  53.1000
# 4  35.0   8.0500

# %%
#  those with object
df.select_dtypes(include=['object']).head()
# Out:
#       sex embarked    who  embark_town alive
# 0    male        S    man  Southampton    no
# 1  female        C  woman    Cherbourg   yes
# 2  female        S  woman  Southampton   yes
# 3  female        S  woman  Southampton   yes
# 4    male        S    man  Southampton    no

# %%
#  those with multiple datatypes
df.select_dtypes(include=['float','number','object']).head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked    who  \
# 0         0       3    male  22.0      1      0   7.2500        S    man
# 1         1       1  female  38.0      1      0  71.2833        C  woman
# 2         1       3  female  26.0      0      0   7.9250        S  woman
# 3         1       1  female  35.0      1      0  53.1000        S  woman
# 4         0       3    male  35.0      0      0   8.0500        S    man
#
#    embark_town alive
# 0  Southampton    no
# 1    Cherbourg   yes
# 2  Southampton   yes
# 3  Southampton   yes
# 4  Southampton    no

# %%
df.select_dtypes(exclude=['number']).head()
# Out:
#       sex embarked  class    who  adult_male deck  embark_town alive  alone
# 0    male        S  Third    man        True  NaN  Southampton    no  False
# 1  female        C  First  woman       False    C    Cherbourg   yes  False
# 2  female        S  Third  woman       False  NaN  Southampton   yes   True
# 3  female        S  First  woman       False    C  Southampton   yes  False
# 4    male        S  Third    man        True  NaN  Southampton    no   True

# %% [markdown]
# # 9- convert numbers into strings

# %%
# creating a dataframe
df = pd.DataFrame({'col a' : ['1','2','3','4','5'],
                   'col b':['6','7','8','9','10']})
df
# Out:
#   col a col b
# 0     1     6
# 1     2     7
# 2     3     8
# 3     4     9
# 4     5    10

# %%
df.dtypes
# Out:
# col a    object
# col b    object
# dtype: object

# %%
# changing datatype to numeric
pd.to_numeric(df['col a'],errors='coerce')
df.dtypes
# Out:
# col a    object
# col b    object
# dtype: object

# %%
#  changing type object to int
df=df.astype({'col a':'int','col b':'object'})

# %%
df.dtypes
# Out:
# col a     int32
# col b    object
# dtype: object

# %%
# changing datatype to numeric
df=pd.to_numeric(df['col b'],errors='coerce')

# %% [markdown]
# # 10- reduce dataframe size

# %%
df=sns.load_dataset('titanic')

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
#  checking the memory usage by this dataset in our computer
df.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 313.7 KB

# %%
# reducing the size by taking a fraction of whole dataset
df.sample(frac=0.1).shape
# Out:
# (89, 15)

# %%
#  taking 0.5 fraction of whole dataset
df.sample(frac=0.5).shape
# Out:
# (446, 15)

# %% [markdown]
# # 11- copy data from clipboard

# %%
# dataset download
import seaborn as sns
import pandas as pd

df=sns.load_dataset('titanic')
df.to_excel('kashti.xlsx')

# %%
# read clipboard in python
df=pd.read_clipboard()
df
# Out:
# Empty DataFrame
# Columns: [https://www.canva.com/design/DAFlmKLC2xI/mtUK36zh5SlFW7aT939a3g/view?utm_content=DAFlmKLC2xI&utm_campaign=designshare&utm_medium=link&utm_source=publishsharelink#1]
# Index: []

# %% [markdown]
# # 12 - split data sets in two frames

# %%
# dataset download
import seaborn as sns
import pandas as pd

df=sns.load_dataset('titanic')
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
len(df)
# Out:
# 891

# %%
df.shape
# Out:
# (891, 15)

# %%
# we have one sample of data set
from random import random
kashti_1 = df.sample(frac=0.5,random_state=1)
kashti_1.shape
# Out:
# (446, 15)

# %%
#  then we just dropped taken dataset from whole dataset
kashti_2= df.drop(kashti_1.index)
kashti_2.shape
# Out:
# (445, 15)

# %%
kashti_1.head()
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 862         1       1  female  48.0      0      0  25.9292        S   First
# 223         0       3    male   NaN      0      0   7.8958        S   Third
# 84          1       2  female  17.0      0      0  10.5000        S  Second
# 680         0       3  female   NaN      0      0   8.1375        Q   Third
# 535         1       2  female   7.0      0      2  26.2500        S  Second
#
#        who  adult_male deck  embark_town alive  alone
# 862  woman       False    D  Southampton   yes   True
# 223    man        True  NaN  Southampton    no   True
# 84   woman       False  NaN  Southampton   yes   True
# 680  woman       False  NaN   Queenstown    no   True
# 535  child       False  NaN  Southampton   yes  False

# %%
kashti_2.head()
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# 15         1       2  female  55.0      0      0  16.0000        S  Second
# 18         0       3  female  31.0      1      0  18.0000        S   Third
#
#       who  adult_male deck  embark_town alive  alone
# 1   woman       False    C    Cherbourg   yes  False
# 7   child       False  NaN  Southampton    no  False
# 10  child       False    G  Southampton   yes  False
# 15  woman       False  NaN  Southampton   yes   True
# 18  woman       False  NaN  Southampton    no  False

# %%
df.shape
# Out:
# (891, 15)

# %%
len(kashti_1) + len(kashti_2)
# Out:
# 891

# %% [markdown]
# # 13 - joining dataset into one dataframe

# %%
df1=kashti_1.append(kashti_2)
df1.shape
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_2684\805721718.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df1=kashti_1.append(kashti_2)
# (891, 15)

# %% [markdown]
# # 14 - filtering a data set

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
df.sex.unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
df[df.sex=="male"]
# Out:
#      survived  pclass   sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3  male  22.0      1      0   7.2500        S   Third
# 4           0       3  male  35.0      0      0   8.0500        S   Third
# 5           0       3  male   NaN      0      0   8.4583        Q   Third
# 6           0       1  male  54.0      0      0  51.8625        S   First
# 7           0       3  male   2.0      3      1  21.0750        S   Third
# ..        ...     ...   ...   ...    ...    ...      ...      ...     ...
# 883         0       2  male  28.0      0      0  10.5000        S  Second
# 884         0       3  male  25.0      0      0   7.0500        S   Third
# 886         0       2  male  27.0      0      0  13.0000        S  Second
# 889         1       1  male  26.0      0      0  30.0000        C   First
# 890         0       3  male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 4      man        True  NaN  Southampton    no   True
# 5      man        True  NaN   Queenstown    no   True
# 6      man        True    E  Southampton    no   True
# 7    child       False  NaN  Southampton    no  False
# ..     ...         ...  ...          ...   ...    ...
# 883    man        True  NaN  Southampton    no   True
# 884    man        True  NaN  Southampton    no   True
# 886    man        True  NaN  Southampton    no   True
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [577 rows x 15 columns]

# %%
df[df.sex=="female"]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 8           1       3  female  27.0      0      2  11.1333        S   Third
# 9           1       2  female  14.0      1      0  30.0708        C  Second
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 880         1       2  female  25.0      0      1  26.0000        S  Second
# 882         0       3  female  22.0      0      0  10.5167        S   Third
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
#
#        who  adult_male deck  embark_town alive  alone
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 8    woman       False  NaN  Southampton   yes  False
# 9    child       False  NaN    Cherbourg   yes  False
# ..     ...         ...  ...          ...   ...    ...
# 880  woman       False  NaN  Southampton   yes  False
# 882  woman       False  NaN  Southampton    no   True
# 885  woman       False  NaN   Queenstown    no  False
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
#
# [314 rows x 15 columns]

# %%
df.age.unique()
# Out:
# array([22.  , 38.  , 26.  , 35.  ,   nan, 54.  ,  2.  , 27.  , 14.  ,
#         4.  , 58.  , 20.  , 39.  , 55.  , 31.  , 34.  , 15.  , 28.  ,
#         8.  , 19.  , 40.  , 66.  , 42.  , 21.  , 18.  ,  3.  ,  7.  ,
#        49.  , 29.  , 65.  , 28.5 ,  5.  , 11.  , 45.  , 17.  , 32.  ,
#        16.  , 25.  ,  0.83, 30.  , 33.  , 23.  , 24.  , 46.  , 59.  ,
#        71.  , 37.  , 47.  , 14.5 , 70.5 , 32.5 , 12.  ,  9.  , 36.5 ,
#        51.  , 55.5 , 40.5 , 44.  ,  1.  , 61.  , 56.  , 50.  , 36.  ,
#        45.5 , 20.5 , 62.  , 41.  , 52.  , 63.  , 23.5 ,  0.92, 43.  ,
#        60.  , 10.  , 64.  , 13.  , 48.  ,  0.75, 53.  , 57.  , 80.  ,
#        70.  , 24.5 ,  6.  ,  0.67, 30.5 ,  0.42, 34.5 , 74.  ])

# %%
df.embarked.unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
df[(df.embarked=="S")].shape
# Out:
# (644, 15)

# %%
df[((df.embark_town=="Southampton") |
    (df.embark_town=="Queenstown")) & 
    (df.sex=="female")]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 8           1       3  female  27.0      0      2  11.1333        S   Third
# 10          1       3  female   4.0      1      1  16.7000        S   Third
# 11          1       1  female  58.0      0      0  26.5500        S   First
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 880         1       2  female  25.0      0      1  26.0000        S  Second
# 882         0       3  female  22.0      0      0  10.5167        S   Third
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
#
#        who  adult_male deck  embark_town alive  alone
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 8    woman       False  NaN  Southampton   yes  False
# 10   child       False    G  Southampton   yes  False
# 11   woman       False    C  Southampton   yes   True
# ..     ...         ...  ...          ...   ...    ...
# 880  woman       False  NaN  Southampton   yes  False
# 882  woman       False  NaN  Southampton    no   True
# 885  woman       False  NaN   Queenstown    no  False
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
#
# [239 rows x 15 columns]

# %%
df[df.embark_town.isin(['Queenstown','Southampton'])].head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
# 5         0       3    male   NaN      0      0   8.4583        Q  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True
# 5    man        True  NaN   Queenstown    no   True

# %%
df[df.age > 30].shape
# df[df.age < 30].shape
# Out:
# (305, 15)

# %% [markdown]
# # 15 filtering by large categories

# %%
df.embark_town.value_counts()
# Out:
# Southampton    644
# Cherbourg      168
# Queenstown      77
# Name: embark_town, dtype: int64

# %%
df.sex.value_counts()
# Out:
# male      577
# female    314
# Name: sex, dtype: int64

# %%
df.age.value_counts().nlargest(5)
# Out:
# 24.0    30
# 22.0    27
# 18.0    26
# 19.0    25
# 28.0    25
# Name: age, dtype: int64

# %%
counts= df.embark_town.value_counts()
counts.nlargest(3)
# Out:
# Southampton    644
# Cherbourg      168
# Queenstown      77
# Name: embark_town, dtype: int64

# %%
counts= df.who.value_counts()
counts.nlargest(3)
# Out:
# man      537
# woman    271
# child     83
# Name: who, dtype: int64

# %%
df[df.who.isin(counts.nlargest(1).index)].head()
# Out:
#     survived  pclass   sex   age  sibsp  parch     fare embarked  class  who  \
# 0          0       3  male  22.0      1      0   7.2500        S  Third  man
# 4          0       3  male  35.0      0      0   8.0500        S  Third  man
# 5          0       3  male   NaN      0      0   8.4583        Q  Third  man
# 6          0       1  male  54.0      0      0  51.8625        S  First  man
# 12         0       3  male  20.0      0      0   8.0500        S  Third  man
#
#     adult_male deck  embark_town alive  alone
# 0         True  NaN  Southampton    no  False
# 4         True  NaN  Southampton    no   True
# 5         True  NaN   Queenstown    no   True
# 6         True    E  Southampton    no   True
# 12        True  NaN  Southampton    no   True

# %% [markdown]
# # 16 - splitting a string into multiple cloumns

# %%
#  import libraries
import pandas as pd

#  read dataset
df=pd.DataFrame({'Name':['Uzair Hussain','Mirza Abbas','Abdul Lahad','Razi Khanzada'],
                        'Location':['Karachi Pakistan','Nawabshah Pakistan','Dadu Pakistan','Hyderabad Pakistan']})
df
# Out:
#             Name            Location
# 0  Uzair Hussain    Karachi Pakistan
# 1    Mirza Abbas  Nawabshah Pakistan
# 2    Abdul Lahad       Dadu Pakistan
# 3  Razi Khanzada  Hyderabad Pakistan

# %%
# splitting into two columns
df[["first name","last name"]] = df.Name.str.split(' ',expand=True)

# %%
# printing those two columns as well
df
# Out:
#             Name            Location first name last name
# 0  Uzair Hussain    Karachi Pakistan      Uzair   Hussain
# 1    Mirza Abbas  Nawabshah Pakistan      Mirza     Abbas
# 2    Abdul Lahad       Dadu Pakistan      Abdul     Lahad
# 3  Razi Khanzada  Hyderabad Pakistan       Razi  Khanzada

# %%
# splitting location into two columns
df[["city","country"]] = df.Location.str.split(' ',expand=True)

# %%
# printing those two columns as well
df
# Out:
#             Name            Location first name last name       city   country
# 0  Uzair Hussain    Karachi Pakistan      Uzair   Hussain    Karachi  Pakistan
# 1    Mirza Abbas  Nawabshah Pakistan      Mirza     Abbas  Nawabshah  Pakistan
# 2    Abdul Lahad       Dadu Pakistan      Abdul     Lahad       Dadu  Pakistan
# 3  Razi Khanzada  Hyderabad Pakistan       Razi  Khanzada  Hyderabad  Pakistan

# %%
# refined dataset
df = df[["first name","last name","city","country"]]
df
# Out:
#   first name last name       city   country
# 0      Uzair   Hussain    Karachi  Pakistan
# 1      Mirza     Abbas  Nawabshah  Pakistan
# 2      Abdul     Lahad       Dadu  Pakistan
# 3       Razi  Khanzada  Hyderabad  Pakistan

# %% [markdown]
# # 17 - Aggregate by multiple groups/functions

# %%
# import libraries
import pandas as pd
import numpy as np
import seaborn as sns

# checking dataset available in seaborn library
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
# import dataset
df=sns.load_dataset('titanic')
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.groupby('who').count()
# Out:
#        survived  pclass  sex  age  sibsp  parch  fare  embarked  class  \
# who
# child        83      83   83   83     83     83    83        83     83
# man         537     537  537  413    537    537   537       537    537
# woman       271     271  271  218    271    271   271       269    271
#
#        adult_male  deck  embark_town  alive  alone
# who
# child          83    13           83     83     83
# man           537    99          537    537    537
# woman         271    91          269    271    271

# %%
df.groupby('who').sum()
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_2684\2979829937.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('who').sum()
#        survived  pclass       age  sibsp  parch        fare  adult_male  alone
# who
# child        49     218    528.67    144    105   2721.2210           0      6
# man          88    1274  13700.50    159     82  13352.0656         537    410
# woman       205     565   6976.00    163    153  12620.6627           0    121

# %%
len(df.groupby('sex'))
# Out:
# 2

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.groupby(['sex','pclass','who']).count()
# Out:
#                      survived  age  sibsp  parch  fare  embarked  class  \
# sex    pclass who
# female 1      child         3    3      3      3     3         3      3
#               woman        91   82     91     91    91        89     91
#        2      child        10   10     10     10    10        10     10
#               woman        66   64     66     66    66        66     66
#        3      child        30   30     30     30    30        30     30
#               woman       114   72    114    114   114       114    114
# male   1      child         3    3      3      3     3         3      3
#               man         119   98    119    119   119       119    119
#        2      child         9    9      9      9     9         9      9
#               man          99   90     99     99    99        99     99
#        3      child        28   28     28     28    28        28     28
#               man         319  225    319    319   319       319    319
#
#                      adult_male  deck  embark_town  alive  alone
# sex    pclass who
# female 1      child           3     3            3      3      3
#               woman          91    78           89     91     91
#        2      child          10     1           10     10     10
#               woman          66     9           66     66     66
#        3      child          30     2           30     30     30
#               woman         114     4          114    114    114
# male   1      child           3     3            3      3      3
#               man           119    91          119    119    119
#        2      child           9     3            9      9      9
#               man            99     3           99     99     99
#        3      child          28     1           28     28     28
#               man           319     5          319    319    319

# %%
df.groupby(['sex','pclass','embarked']).count()
# Out:
#                         survived  age  sibsp  parch  fare  class  who  \
# sex    pclass embarked
# female 1      C               43   38     43     43    43     43   43
#               Q                1    1      1      1     1      1    1
#               S               48   44     48     48    48     48   48
#        2      C                7    7      7      7     7      7    7
#               Q                2    1      2      2     2      2    2
#               S               67   66     67     67    67     67   67
#        3      C               23   16     23     23    23     23   23
#               Q               33   10     33     33    33     33   33
#               S               88   76     88     88    88     88   88
# male   1      C               42   36     42     42    42     42   42
#               Q                1    1      1      1     1      1    1
#               S               79   64     79     79    79     79   79
#        2      C               10    8     10     10    10     10   10
#               Q                1    1      1      1     1      1    1
#               S               97   90     97     97    97     97   97
#        3      C               43   25     43     43    43     43   43
#               Q               39   14     39     39    39     39   39
#               S              265  214    265    265   265    265  265
#
#                         adult_male  deck  embark_town  alive  alone
# sex    pclass embarked
# female 1      C                 43    35           43     43     43
#               Q                  1     1            1      1      1
#               S                 48    43           48     48     48
#        2      C                  7     1            7      7      7
#               Q                  2     1            2      2      2
#               S                 67     8           67     67     67
#        3      C                 23     1           23     23     23
#               Q                 33     0           33     33     33
#               S                 88     5           88     88     88
# male   1      C                 42    31           42     42     42
#               Q                  1     1            1      1      1
#               S                 79    62           79     79     79
#        2      C                 10     1           10     10     10
#               Q                  1     0            1      1      1
#               S                 97     5           97     97     97
#        3      C                 43     0           43     43     43
#               Q                 39     1           39     39     39
#               S                265     5          265    265    265

# %%
df.groupby(['sex','pclass','embark_town']).count()
# Out:
#                            survived  age  sibsp  parch  fare  embarked  class  \
# sex    pclass embark_town
# female 1      Cherbourg          43   38     43     43    43        43     43
#               Queenstown          1    1      1      1     1         1      1
#               Southampton        48   44     48     48    48        48     48
#        2      Cherbourg           7    7      7      7     7         7      7
#               Queenstown          2    1      2      2     2         2      2
#               Southampton        67   66     67     67    67        67     67
#        3      Cherbourg          23   16     23     23    23        23     23
#               Queenstown         33   10     33     33    33        33     33
#               Southampton        88   76     88     88    88        88     88
# male   1      Cherbourg          42   36     42     42    42        42     42
#               Queenstown          1    1      1      1     1         1      1
#               Southampton        79   64     79     79    79        79     79
#        2      Cherbourg          10    8     10     10    10        10     10
#               Queenstown          1    1      1      1     1         1      1
#               Southampton        97   90     97     97    97        97     97
#        3      Cherbourg          43   25     43     43    43        43     43
#               Queenstown         39   14     39     39    39        39     39
#               Southampton       265  214    265    265   265       265    265
#
#                            who  adult_male  deck  alive  alone
# sex    pclass embark_town
# female 1      Cherbourg     43          43    35     43     43
#               Queenstown     1           1     1      1      1
#               Southampton   48          48    43     48     48
#        2      Cherbourg      7           7     1      7      7
#               Queenstown     2           2     1      2      2
#               Southampton   67          67     8     67     67
#        3      Cherbourg     23          23     1     23     23
#               Queenstown    33          33     0     33     33
#               Southampton   88          88     5     88     88
# male   1      Cherbourg     42          42    31     42     42
#               Queenstown     1           1     1      1      1
#               Southampton   79          79    62     79     79
#        2      Cherbourg     10          10     1     10     10
#               Queenstown     1           1     0      1      1
#               Southampton   97          97     5     97     97
#        3      Cherbourg     43          43     0     43     43
#               Queenstown    39          39     1     39     39
#               Southampton  265         265     5    265    265

# %% [markdown]
# # 18 - select specific rows and columns

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df[['sex','class','age','parch']]
# Out:
#         sex   class   age  parch
# 0      male   Third  22.0      0
# 1    female   First  38.0      0
# 2    female   Third  26.0      0
# 3    female   First  35.0      0
# 4      male   Third  35.0      0
# ..      ...     ...   ...    ...
# 886    male  Second  27.0      0
# 887  female   First  19.0      0
# 888  female   Third   NaN      2
# 889    male   First  26.0      0
# 890    male   Third  32.0      0
#
# [891 rows x 4 columns]

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df[['sex','class']]
# Out:
#         sex   class
# 0      male   Third
# 1    female   First
# 2    female   Third
# 3    female   First
# 4      male   Third
# ..      ...     ...
# 886    male  Second
# 887  female   First
# 888  female   Third
# 889    male   First
# 890    male   Third
#
# [891 rows x 2 columns]

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
# df.describe().loc[['min','25%','50%','75%','max']]
# or
df.describe().loc['min':'max','survived':'age']
# Out:
#      survived  pclass     age
# min       0.0     1.0   0.420
# 25%       0.0     2.0  20.125
# 50%       0.0     3.0  28.000
# 75%       1.0     3.0  38.000
# max       1.0     3.0  80.000

# %% [markdown]
# # 19- Reshape multiindex series

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.survived.mean()
# Out:
# 0.3838383838383838

# %%
df.groupby(['sex','class']).survived.mean()
# Out:
# sex     class
# female  First     0.968085
#         Second    0.921053
#         Third     0.500000
# male    First     0.368852
#         Second    0.157407
#         Third     0.135447
# Name: survived, dtype: float64

# %%
df.groupby(['sex','class']).survived.mean().unstack()
# Out:
# class      First    Second     Third
# sex
# female  0.968085  0.921053  0.500000
# male    0.368852  0.157407  0.135447

# %% [markdown]
# # 20- Continous to categorical data conversion

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.age.head()
# Out:
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# Name: age, dtype: float64

# %%
# pd.cut(df.age,bins=[0,18,25,99],labels=['child','young_adult','adult']).head()
df['new_age'] = pd.cut(df.age,bins=[0,18,25,99],labels=['child','young_adult','adult']).head()
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone      new_age
# 0    man        True  NaN  Southampton    no  False  young_adult
# 1  woman       False    C    Cherbourg   yes  False        adult
# 2  woman       False  NaN  Southampton   yes   True        adult
# 3  woman       False    C  Southampton   yes  False        adult
# 4    man        True  NaN  Southampton    no   True        adult

# %% [markdown]
# # 21- Convert one set of values into another one

# %%
df.sex.head()
# Out:
# 0      male
# 1    female
# 2    female
# 3    female
# 4      male
# Name: sex, dtype: object

# %%
df.sex.map({'male':0,'female':1})
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    1
# 889    0
# 890    0
# Name: sex, Length: 891, dtype: int64

# %%
df['sex_number']=df.sex.map({'male':0,'female':1})

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone      new_age  sex_number
# 0      man        True  NaN  Southampton    no  False  young_adult           0
# 1    woman       False    C    Cherbourg   yes  False        adult           1
# 2    woman       False  NaN  Southampton   yes   True        adult           1
# 3    woman       False    C  Southampton   yes  False        adult           1
# 4      man        True  NaN  Southampton    no   True        adult           0
# ..     ...         ...  ...          ...   ...    ...          ...         ...
# 886    man        True  NaN  Southampton    no   True          NaN           0
# 887  woman       False    B  Southampton   yes   True          NaN           1
# 888  woman       False  NaN  Southampton    no  False          NaN           1
# 889    man        True    C    Cherbourg   yes   True          NaN           0
# 890    man        True  NaN   Queenstown    no   True          NaN           0
#
# [891 rows x 17 columns]

# %%
df.embarked.count()
# Out:
# 889

# %%
df.embarked.unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
df['embarked_number']=df.embarked.factorize()[0]

# %%
df.head(10)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0         0       3    male  22.0      1      0   7.2500        S   Third
# 1         1       1  female  38.0      1      0  71.2833        C   First
# 2         1       3  female  26.0      0      0   7.9250        S   Third
# 3         1       1  female  35.0      1      0  53.1000        S   First
# 4         0       3    male  35.0      0      0   8.0500        S   Third
# 5         0       3    male   NaN      0      0   8.4583        Q   Third
# 6         0       1    male  54.0      0      0  51.8625        S   First
# 7         0       3    male   2.0      3      1  21.0750        S   Third
# 8         1       3  female  27.0      0      2  11.1333        S   Third
# 9         1       2  female  14.0      1      0  30.0708        C  Second
#
#      who  adult_male deck  embark_town alive  alone      new_age  sex_number  \
# 0    man        True  NaN  Southampton    no  False  young_adult           0
# 1  woman       False    C    Cherbourg   yes  False        adult           1
# 2  woman       False  NaN  Southampton   yes   True        adult           1
# 3  woman       False    C  Southampton   yes  False        adult           1
# 4    man        True  NaN  Southampton    no   True        adult           0
# 5    man        True  NaN   Queenstown    no   True          NaN           0
# 6    man        True    E  Southampton    no   True          NaN           0
# 7  child       False  NaN  Southampton    no  False          NaN           0
# 8  woman       False  NaN  Southampton   yes  False          NaN           1
# 9  child       False  NaN    Cherbourg   yes  False          NaN           1
#
#    embarked_number
# 0                0
# 1                1
# 2                0
# 3                0
# 4                0
# 5                2
# 6                0
# 7                0
# 8                0
# 9                1

# %% [markdown]
# # 22- Transpose a wide dataframe

# %%
import pandas as pd
import numpy as np

# %%
#  creating a new df
df=pd.DataFrame(np.random.rand(200,25),columns=list('abcdefghijklmnopqrstuvwxy'))

# %%
df.head(10)
# Out:
#           a         b         c         d         e         f         g  \
# 0  0.035700  0.714813  0.181090  0.933330  0.812946  0.263995  0.359682
# 1  0.126069  0.339198  0.074490  0.448388  0.599904  0.750146  0.923672
# 2  0.045663  0.423889  0.936590  0.022775  0.576949  0.504423  0.500609
# 3  0.658404  0.563169  0.724192  0.327120  0.676800  0.508579  0.174258
# 4  0.349278  0.090665  0.072340  0.839350  0.281607  0.067166  0.883032
# 5  0.725338  0.187301  0.823549  0.900880  0.696612  0.781339  0.328178
# 6  0.918262  0.462585  0.119486  0.131763  0.745028  0.823505  0.136683
# 7  0.711036  0.339936  0.660274  0.175860  0.875049  0.118401  0.497585
# 8  0.117265  0.191180  0.483083  0.575440  0.864487  0.558058  0.472566
# 9  0.380862  0.956148  0.383210  0.163445  0.811104  0.138440  0.167159
#
#           h         i         j  ...         p         q         r         s  \
# 0  0.026546  0.201665  0.512771  ...  0.699650  0.478804  0.938314  0.593602
# 1  0.768237  0.258338  0.498583  ...  0.965478  0.426791  0.443003  0.606649
# 2  0.706059  0.116903  0.011263  ...  0.427546  0.832408  0.049110  0.350457
# 3  0.254966  0.939682  0.284386  ...  0.599488  0.120187  0.816149  0.451134
# 4  0.593522  0.183871  0.799468  ...  0.595839  0.803304  0.114285  0.197655
# 5  0.063917  0.940359  0.088158  ...  0.487685  0.174654  0.354905  0.082800
# 6  0.699769  0.387843  0.409061  ...  0.244704  0.400198  0.522988  0.799730
# 7  0.866424  0.404341  0.720554  ...  0.690375  0.667880  0.167846  0.408213
# 8  0.964806  0.609996  0.103704  ...  0.032041  0.439851  0.474442  0.793229
# 9  0.955073  0.680785  0.009286  ...  0.449639  0.523204  0.264957  0.973463
#
#           t         u         v         w         x         y
# 0  0.019186  0.522938  0.484101  0.037867  0.295254  0.816763
# 1  0.913104  0.880087  0.471649  0.994341  0.880424  0.080063
# 2  0.456260  0.978027  0.917039  0.725870  0.930068  0.756431
# 3  0.364708  0.284771  0.342296  0.491747  0.613262  0.025414
# 4  0.856139  0.117013  0.694551  0.082075  0.925261  0.228671
# 5  0.495416  0.968302  0.728905  0.859796  0.089301  0.686415
# 6  0.663318  0.054855  0.023540  0.131795  0.193663  0.554085
# 7  0.767821  0.535534  0.570683  0.357957  0.878946  0.143622
# 8  0.182731  0.071347  0.908322  0.565931  0.994587  0.007485
# 9  0.474583  0.393483  0.436901  0.478353  0.344470  0.387014
#
# [10 rows x 25 columns]

# %%
df.head(10).T
# Out:
#           0         1         2         3         4         5         6  \
# a  0.035700  0.126069  0.045663  0.658404  0.349278  0.725338  0.918262
# b  0.714813  0.339198  0.423889  0.563169  0.090665  0.187301  0.462585
# c  0.181090  0.074490  0.936590  0.724192  0.072340  0.823549  0.119486
# d  0.933330  0.448388  0.022775  0.327120  0.839350  0.900880  0.131763
# e  0.812946  0.599904  0.576949  0.676800  0.281607  0.696612  0.745028
# f  0.263995  0.750146  0.504423  0.508579  0.067166  0.781339  0.823505
# g  0.359682  0.923672  0.500609  0.174258  0.883032  0.328178  0.136683
# h  0.026546  0.768237  0.706059  0.254966  0.593522  0.063917  0.699769
# i  0.201665  0.258338  0.116903  0.939682  0.183871  0.940359  0.387843
# j  0.512771  0.498583  0.011263  0.284386  0.799468  0.088158  0.409061
# k  0.805870  0.547117  0.370622  0.924409  0.835228  0.252728  0.801635
# l  0.989576  0.193135  0.217850  0.166373  0.903012  0.093196  0.666439
# m  0.448480  0.390651  0.320626  0.594003  0.370201  0.773300  0.735196
# n  0.516551  0.884258  0.204094  0.369665  0.915345  0.788156  0.914463
# o  0.027390  0.827497  0.720300  0.866125  0.821634  0.482078  0.451713
# p  0.699650  0.965478  0.427546  0.599488  0.595839  0.487685  0.244704
# q  0.478804  0.426791  0.832408  0.120187  0.803304  0.174654  0.400198
# r  0.938314  0.443003  0.049110  0.816149  0.114285  0.354905  0.522988
# s  0.593602  0.606649  0.350457  0.451134  0.197655  0.082800  0.799730
# t  0.019186  0.913104  0.456260  0.364708  0.856139  0.495416  0.663318
# u  0.522938  0.880087  0.978027  0.284771  0.117013  0.968302  0.054855
# v  0.484101  0.471649  0.917039  0.342296  0.694551  0.728905  0.023540
# w  0.037867  0.994341  0.725870  0.491747  0.082075  0.859796  0.131795
# x  0.295254  0.880424  0.930068  0.613262  0.925261  0.089301  0.193663
# y  0.816763  0.080063  0.756431  0.025414  0.228671  0.686415  0.554085
#
#           7         8         9
# a  0.711036  0.117265  0.380862
# b  0.339936  0.191180  0.956148
# c  0.660274  0.483083  0.383210
# d  0.175860  0.575440  0.163445
# e  0.875049  0.864487  0.811104
# f  0.118401  0.558058  0.138440
# g  0.497585  0.472566  0.167159
# h  0.866424  0.964806  0.955073
# i  0.404341  0.609996  0.680785
# j  0.720554  0.103704  0.009286
# k  0.072143  0.940578  0.310804
# l  0.795075  0.555046  0.792827
# m  0.807773  0.265148  0.753403
# n  0.747861  0.933762  0.658396
# o  0.017573  0.552044  0.621828
# p  0.690375  0.032041  0.449639
# q  0.667880  0.439851  0.523204
# r  0.167846  0.474442  0.264957
# s  0.408213  0.793229  0.973463
# t  0.767821  0.182731  0.474583
# u  0.535534  0.071347  0.393483
# v  0.570683  0.908322  0.436901
# w  0.357957  0.565931  0.478353
# x  0.878946  0.994587  0.344470
# y  0.143622  0.007485  0.387014

# %%
df.describe()
# Out:
#                 a           b           c           d           e           f  \
# count  200.000000  200.000000  200.000000  200.000000  200.000000  200.000000
# mean     0.483985    0.482321    0.500850    0.508619    0.496301    0.477552
# std      0.272766    0.284460    0.299934    0.287198    0.301878    0.285468
# min      0.004125    0.002886    0.002797    0.005227    0.001104    0.000915
# 25%      0.252669    0.265733    0.219218    0.257343    0.220418    0.226006
# 50%      0.483002    0.448192    0.483069    0.516748    0.515011    0.473374
# 75%      0.726767    0.735203    0.757603    0.741265    0.771948    0.744589
# max      0.998587    0.997871    0.995762    0.997799    0.998170    0.990884
#
#                 g           h           i           j  ...           p  \
# count  200.000000  200.000000  200.000000  200.000000  ...  200.000000
# mean     0.502427    0.516270    0.506258    0.546885  ...    0.518328
# std      0.299179    0.282964    0.296375    0.289105  ...    0.293298
# min      0.001457    0.002296    0.002661    0.009286  ...    0.023086
# 25%      0.248146    0.303993    0.259574    0.346344  ...    0.253071
# 50%      0.491316    0.504972    0.485277    0.580511  ...    0.534141
# 75%      0.773055    0.739726    0.783248    0.789161  ...    0.793411
# max      0.994778    0.997763    0.995315    0.996864  ...    0.994628
#
#                 q           r           s           t           u           v  \
# count  200.000000  200.000000  200.000000  200.000000  200.000000  200.000000
# mean     0.499186    0.514362    0.474120    0.499439    0.452981    0.519810
# std      0.268358    0.272300    0.295302    0.286999    0.290445    0.291948
# min      0.006523    0.004177    0.005847    0.002803    0.000360    0.007919
# 25%      0.272082    0.282540    0.209454    0.257778    0.191678    0.279846
# 50%      0.500000    0.524689    0.480483    0.501399    0.423576    0.521607
# 75%      0.700922    0.714302    0.708031    0.736206    0.699400    0.768068
# max      0.993009    0.997750    0.993270    0.994661    0.989167    0.997852
#
#                 w           x           y
# count  200.000000  200.000000  200.000000
# mean     0.474961    0.515265    0.485617
# std      0.309561    0.298776    0.295193
# min      0.004697    0.000989    0.004988
# 25%      0.191805    0.249033    0.224490
# 50%      0.467800    0.510948    0.456664
# 75%      0.751771    0.799656    0.755429
# max      0.995184    0.997358    0.999499
#
# [8 rows x 25 columns]

# %%
df.T
# Out:
#         0         1         2         3         4         5         6    \
# a  0.035700  0.126069  0.045663  0.658404  0.349278  0.725338  0.918262
# b  0.714813  0.339198  0.423889  0.563169  0.090665  0.187301  0.462585
# c  0.181090  0.074490  0.936590  0.724192  0.072340  0.823549  0.119486
# d  0.933330  0.448388  0.022775  0.327120  0.839350  0.900880  0.131763
# e  0.812946  0.599904  0.576949  0.676800  0.281607  0.696612  0.745028
# f  0.263995  0.750146  0.504423  0.508579  0.067166  0.781339  0.823505
# g  0.359682  0.923672  0.500609  0.174258  0.883032  0.328178  0.136683
# h  0.026546  0.768237  0.706059  0.254966  0.593522  0.063917  0.699769
# i  0.201665  0.258338  0.116903  0.939682  0.183871  0.940359  0.387843
# j  0.512771  0.498583  0.011263  0.284386  0.799468  0.088158  0.409061
# k  0.805870  0.547117  0.370622  0.924409  0.835228  0.252728  0.801635
# l  0.989576  0.193135  0.217850  0.166373  0.903012  0.093196  0.666439
# m  0.448480  0.390651  0.320626  0.594003  0.370201  0.773300  0.735196
# n  0.516551  0.884258  0.204094  0.369665  0.915345  0.788156  0.914463
# o  0.027390  0.827497  0.720300  0.866125  0.821634  0.482078  0.451713
# p  0.699650  0.965478  0.427546  0.599488  0.595839  0.487685  0.244704
# q  0.478804  0.426791  0.832408  0.120187  0.803304  0.174654  0.400198
# r  0.938314  0.443003  0.049110  0.816149  0.114285  0.354905  0.522988
# s  0.593602  0.606649  0.350457  0.451134  0.197655  0.082800  0.799730
# t  0.019186  0.913104  0.456260  0.364708  0.856139  0.495416  0.663318
# u  0.522938  0.880087  0.978027  0.284771  0.117013  0.968302  0.054855
# v  0.484101  0.471649  0.917039  0.342296  0.694551  0.728905  0.023540
# w  0.037867  0.994341  0.725870  0.491747  0.082075  0.859796  0.131795
# x  0.295254  0.880424  0.930068  0.613262  0.925261  0.089301  0.193663
# y  0.816763  0.080063  0.756431  0.025414  0.228671  0.686415  0.554085
#
#         7         8         9    ...       190       191       192       193  \
# a  0.711036  0.117265  0.380862  ...  0.304073  0.759624  0.417447  0.955767
# b  0.339936  0.191180  0.956148  ...  0.357657  0.399186  0.777692  0.224754
# c  0.660274  0.483083  0.383210  ...  0.430471  0.850616  0.403786  0.372296
# d  0.175860  0.575440  0.163445  ...  0.141018  0.602482  0.745989  0.007894
# e  0.875049  0.864487  0.811104  ...  0.849348  0.025624  0.611681  0.856829
# f  0.118401  0.558058  0.138440  ...  0.226181  0.769142  0.225482  0.353625
# g  0.497585  0.472566  0.167159  ...  0.123806  0.001457  0.951311  0.651887
# h  0.866424  0.964806  0.955073  ...  0.045333  0.008839  0.286563  0.973541
# i  0.404341  0.609996  0.680785  ...  0.343715  0.368385  0.327495  0.932682
# j  0.720554  0.103704  0.009286  ...  0.769644  0.690066  0.294284  0.084084
# k  0.072143  0.940578  0.310804  ...  0.359319  0.626271  0.539788  0.900456
# l  0.795075  0.555046  0.792827  ...  0.141292  0.625063  0.723708  0.305712
# m  0.807773  0.265148  0.753403  ...  0.315716  0.465682  0.928213  0.774015
# n  0.747861  0.933762  0.658396  ...  0.474438  0.901037  0.658348  0.082984
# o  0.017573  0.552044  0.621828  ...  0.005954  0.111014  0.664655  0.395283
# p  0.690375  0.032041  0.449639  ...  0.037051  0.194676  0.688306  0.507800
# q  0.667880  0.439851  0.523204  ...  0.682271  0.503957  0.290029  0.932416
# r  0.167846  0.474442  0.264957  ...  0.596109  0.759838  0.023589  0.173065
# s  0.408213  0.793229  0.973463  ...  0.887567  0.886150  0.471705  0.853131
# t  0.767821  0.182731  0.474583  ...  0.675651  0.617409  0.428179  0.377090
# u  0.535534  0.071347  0.393483  ...  0.157395  0.063891  0.795102  0.138294
# v  0.570683  0.908322  0.436901  ...  0.166849  0.788761  0.540577  0.018107
# w  0.357957  0.565931  0.478353  ...  0.928663  0.837360  0.054141  0.666533
# x  0.878946  0.994587  0.344470  ...  0.869613  0.846731  0.783770  0.876943
# y  0.143622  0.007485  0.387014  ...  0.105146  0.764381  0.186097  0.735295
#
#         194       195       196       197       198       199
# a  0.294784  0.481571  0.310156  0.233963  0.205034  0.595893
# b  0.963520  0.542610  0.719177  0.712328  0.699407  0.144446
# c  0.743669  0.871802  0.843784  0.484078  0.217868  0.028343
# d  0.647419  0.140454  0.944281  0.366378  0.299886  0.017473
# e  0.089005  0.578727  0.497455  0.321768  0.671490  0.441680
# f  0.122759  0.053831  0.260833  0.696762  0.146440  0.185863
# g  0.145938  0.294058  0.824031  0.118502  0.737597  0.985501
# h  0.386582  0.631866  0.143790  0.007794  0.396768  0.750074
# i  0.345581  0.660775  0.524105  0.375234  0.160698  0.053243
# j  0.679884  0.695161  0.407590  0.301530  0.702207  0.973697
# k  0.183650  0.851319  0.274228  0.054982  0.341345  0.789824
# l  0.675561  0.799661  0.511300  0.582752  0.521515  0.351573
# m  0.205014  0.770953  0.782780  0.386370  0.836256  0.670364
# n  0.116980  0.758376  0.424746  0.037874  0.127559  0.153228
# o  0.696159  0.878313  0.391212  0.685315  0.316178  0.047078
# p  0.170062  0.909459  0.871195  0.148724  0.891717  0.970733
# q  0.821526  0.478010  0.748780  0.896400  0.685013  0.839970
# r  0.725477  0.903788  0.229820  0.362663  0.675183  0.716694
# s  0.944001  0.494194  0.379981  0.487468  0.928551  0.622391
# t  0.231861  0.457412  0.781809  0.019273  0.002803  0.387195
# u  0.982669  0.165992  0.404718  0.814860  0.650502  0.000360
# v  0.947824  0.297858  0.071248  0.109921  0.808814  0.513258
# w  0.362831  0.053311  0.967951  0.924624  0.177788  0.396799
# x  0.000989  0.200421  0.444550  0.952848  0.088076  0.577783
# y  0.601378  0.275488  0.728404  0.700949  0.055390  0.562694
#
# [25 rows x 200 columns]

# %%
df.describe().T
# Out:
#    count      mean       std       min       25%       50%       75%       max
# a  200.0  0.483985  0.272766  0.004125  0.252669  0.483002  0.726767  0.998587
# b  200.0  0.482321  0.284460  0.002886  0.265733  0.448192  0.735203  0.997871
# c  200.0  0.500850  0.299934  0.002797  0.219218  0.483069  0.757603  0.995762
# d  200.0  0.508619  0.287198  0.005227  0.257343  0.516748  0.741265  0.997799
# e  200.0  0.496301  0.301878  0.001104  0.220418  0.515011  0.771948  0.998170
# f  200.0  0.477552  0.285468  0.000915  0.226006  0.473374  0.744589  0.990884
# g  200.0  0.502427  0.299179  0.001457  0.248146  0.491316  0.773055  0.994778
# h  200.0  0.516270  0.282964  0.002296  0.303993  0.504972  0.739726  0.997763
# i  200.0  0.506258  0.296375  0.002661  0.259574  0.485277  0.783248  0.995315
# j  200.0  0.546885  0.289105  0.009286  0.346344  0.580511  0.789161  0.996864
# k  200.0  0.502576  0.296394  0.001495  0.241063  0.505238  0.765541  0.992655
# l  200.0  0.492495  0.293900  0.003551  0.239267  0.509046  0.751693  0.993453
# m  200.0  0.488098  0.277194  0.000652  0.281891  0.470316  0.756188  0.999995
# n  200.0  0.495290  0.297731  0.001995  0.238646  0.502312  0.748843  0.979667
# o  200.0  0.523101  0.285904  0.000486  0.284171  0.544437  0.785507  0.995887
# p  200.0  0.518328  0.293298  0.023086  0.253071  0.534141  0.793411  0.994628
# q  200.0  0.499186  0.268358  0.006523  0.272082  0.500000  0.700922  0.993009
# r  200.0  0.514362  0.272300  0.004177  0.282540  0.524689  0.714302  0.997750
# s  200.0  0.474120  0.295302  0.005847  0.209454  0.480483  0.708031  0.993270
# t  200.0  0.499439  0.286999  0.002803  0.257778  0.501399  0.736206  0.994661
# u  200.0  0.452981  0.290445  0.000360  0.191678  0.423576  0.699400  0.989167
# v  200.0  0.519810  0.291948  0.007919  0.279846  0.521607  0.768068  0.997852
# w  200.0  0.474961  0.309561  0.004697  0.191805  0.467800  0.751771  0.995184
# x  200.0  0.515265  0.298776  0.000989  0.249033  0.510948  0.799656  0.997358
# y  200.0  0.485617  0.295193  0.004988  0.224490  0.456664  0.755429  0.999499

# %%
df.describe().T.to_csv("transposed_data.csv")

# %% [markdown]
# # 23- Reshaping a dataframe

# %%
import pandas as pd
import numpy as np

# %%
fasla = pd.DataFrame([['12345',100,200,300],['34567',400,500,600],
                      ['67890',700,800,900]],columns=['zip','factory','warehouse','retail'])

# %%
fasla.head().T
# Out:
#                0      1      2
# zip        12345  34567  67890
# factory      100    400    700
# warehouse    200    500    800
# retail       300    600    900

# %%
fasla2 = pd.DataFrame([[1,'12345','factory'],[2,'34567','warehouse']],columns=['user_id','zip','location_type'])
fasla2.head()
# Out:
#    user_id    zip location_type
# 0        1  12345       factory
# 1        2  34567     warehouse

# %%
f
