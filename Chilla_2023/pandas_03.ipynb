# %% [markdown]
# # PANDAS - DAY 3 ( TIPS AND TRICKS )

# %% [markdown]
# ## Table of Contents:
#
# [1. how-to-find-the-version](#01--how-to-find-the-version)\
# [2. making-a-data-frame](#02--making-a-data-frame)\
# [3. using-numpy-to-create-dataframe](#3--using-numpy-to-create-dataframe)\
# [4. sing-template-data](#4-using-template-data)\
# [5. using-your-own-data](#5-using-your-own-data)\
# [6. reverse-row-order](#6-reverse-row-order)\
# [7. reverse-colun-order](#7--reverse-colun-order)\
# [8. select-a-cloumn-by-a-data-type](#8--select-a-cloumn-by-a-data-type)\
# [9. convert-numbers-into-strings](#9--convert-numbers-into-strings)\
# [10. reduce-dataframe-size](#10--reduce-dataframe-size)\
# [11. copy-data-from-clipboard](#11--copy-data-from-clipboard)\
# [12. split-data-sets-in-two-frames](#12---split-data-sets-in-two-frames)\
# [13. joining-dataset-into-one-dataframe](#13---joining-dataset-into-one-dataframe)\
# [14. filtering-a-data-set](#14---filtering-a-data-set)\
# [15. filtering-by-large-categories](#15-filtering-by-large-categories)\
# [16. splitting-a-string-into-multiple-cloumns](#16---splitting-a-string-into-multiple-cloumns)\
# [17. aggregate-by-multiple-groupsfunctions](#17---aggregate-by-multiple-groupsfunctions)\
# [18. select-specific-rows-and-columns](#18---select-specific-rows-and-columns)

# %% [markdown]
# ### 01 . How to find the version?

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '1.5.3'

# %%
pd.show_versions()
# Out:
# c:\Users\Administrator\AppData\Local\Programs\Python\Python311\Lib\site-packages\_distutils_hack\__init__.py:33: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# INSTALLED VERSIONS
# ------------------
# commit           : 2e218d10984e9919f0296931d92ea851c6a6faf5
# python           : 3.11.1.final.0
# python-bits      : 64
# OS               : Windows
# OS-release       : 10
# Version          : 10.0.22000
# machine          : AMD64
# processor        : Intel64 Family 6 Model 78 Stepping 3, GenuineIntel
# byteorder        : little
# LC_ALL           : None
# LANG             : None
# LOCALE           : English_United States.1252
#
# pandas           : 1.5.3
# numpy            : 1.24.2
# pytz             : 2022.7.1
# dateutil         : 2.8.2
# setuptools       : 65.5.0
# pip              : 23.1.2
# Cython           : None
# pytest           : None
# hypothesis       : None
# sphinx           : None
# blosc            : None
# feather          : None
# xlsxwriter       : None
# lxml.etree       : None
# html5lib         : None
# pymysql          : None
# psycopg2         : None
# jinja2           : 3.1.2
# IPython          : 8.13.2
# pandas_datareader: None
# bs4              : 4.11.2
# bottleneck       : None
# brotli           : None
# fastparquet      : None
# fsspec           : None
# gcsfs            : None
# matplotlib       : 3.7.1
# numba            : None
# numexpr          : None
# odfpy            : None
# openpyxl         : 3.1.2
# pandas_gbq       : None
# pyarrow          : None
# pyreadstat       : None
# pyxlsb           : None
# s3fs             : None
# scipy            : None
# snappy           : None
# sqlalchemy       : None
# tables           : None
# tabulate         : None
# xarray           : None
# xlrd             : None
# xlwt             : None
# zstandard        : None
# tzdata           : None

# %% [markdown]
# ### 02- Making a Data Frame

# %%
df=pd.DataFrame({'Name ':["Uzair","Abbas","Lahad","Razi","Bilal"],'Age ': [20,19,21,22,19]})

# %%
df
# Out:
#    Name   Age
# 0  Uzair    20
# 1  Abbas    19
# 2  Lahad    21
# 3   Razi    22
# 4  Bilal    19

# %%
df.head()
# Out:
#    Name   Age
# 0  Uzair    20
# 1  Abbas    19
# 2  Lahad    21
# 3   Razi    22
# 4  Bilal    19

# %%
df.tail()
# Out:
#    Name   Age
# 0  Uzair    20
# 1  Abbas    19
# 2  Lahad    21
# 3   Razi    22
# 4  Bilal    19

# %%
df
# Out:
#    Name   Age
# 0  Uzair    20
# 1  Abbas    19
# 2  Lahad    21
# 3   Razi    22
# 4  Bilal    19

# %% [markdown]
# # 3- using numpy to create dataframe

# %%
# numpy array to create dataframe
import numpy as np
arr=np.array([['Uzair',20],['Abbas',19],['Lahad',21],['Razi',22],['Bilal',19]])
# arr
df=pd.DataFrame(arr,columns=['Name','Age'])
df
# Out:
#     Name Age
# 0  Uzair  20
# 1  Abbas  19
# 2  Lahad  21
# 3   Razi  22
# 4  Bilal  19

# %%
# numpy array data frame
pd.DataFrame(np.random.rand(5,2))
pd.DataFrame(np.random.rand(5,2), columns=list("AB"))
# Out:
#           A         B
# 0  0.135874  0.724882
# 1  0.747026  0.630566
# 2  0.043767  0.424784
# 3  0.605738  0.886657
# 4  0.126661  0.031505

# %%
pd.DataFrame(np.random.rand(50,20))
# Out:
#           0         1         2         3         4         5         6   \
# 0   0
# 24  0.051079  0.312110  0.746404  0.629251  0.712154  0.711134
# 25  0.468789  0.232470  0.843698  0.692472  0.849921  0.473912
# 26  0.922127  0.012103  0.554446  0.815144  0.838758  0.205065
# 27  0.939668  0.262343  0.545897  0.288378  0.709963  0.882881
# 28  0.693848  0.268124  0.065262  0.870963  0.463070  0.735112
# 29  0.237677  0.894573  0.980304  0.175439  0.497805  0.965101
# 30  0.427221  0.961453  0.858161  0.145231  0.218538  0.527085
# 31  0.652513  0.341537  0.938648  0.553928  0.050400  0.709751
# 32  0.852893  0.194953  0.572095  0.276880  0.418022  0.975082
# 33  0.427150  0.014064  0.062885  0.823621  0.526198  0.524718
# 34  0.851534  0.094971  0.392943  0.777015  0.524941  0.859832
# 35  0.519651  0.559859  0.032852  0.346527  0.872408  0.850470
# 36  0.222102  0.611793  0.321467  0.172299  0.405162  0.865265
# 37  0.301747  0.587252  0.728893  0.697364  0.778585  0.956750
# 38  0.626839  0.805707  0.145171  0.312125  0.465520  0.947684
# 39  0.044551  0.934416  0.472960  0.394004  0.001381  0.519073
# 40  0.913386  0.368547  0.520580  0.966125  0.233912  0.164761
# 41  0.308703  0.325479  0.639190  0.649269  0.491121  0.395235
# 42  0.176158  0.173039  0.520925  0.669903  0.392719  0.986720
# 43  0.824936  0.765820  0.069553  0.550014  0.768573  0.539578
# 44  0.382916  0.470938  0.640593  0.047543  0.771750  0.860769
# 45  0.842526  0.479188  0.842619  0.414379  0.911329  0.116002
# 46  0.240429  0.756970  0.536640  0.035452  0.136057  0.700849
# 47  0.767534  0.670290  0.022101  0.718539  0.113686  0.219440
# 48  0.832226  0.364062  0.561014  0.393234  0.235549  0.630661
# 49  0.996042  0.799499  0.755830  0.970317  0.853480  0.259768

# %%
df
# Out:
#     Name Age
# 0  Uzair  20
# 1  Abbas  19
# 2  Lahad  21
# 3   Razi  22
# 4  Bilal  19

# %%
# how to rename column names
df=pd.DataFrame({'A col ':[1,2,3,4,5],'B col ': [20,19,18,17,16]})

# %%
df.rename(columns={'A col': 'a col','B col':'b col'}, inplace=True)

# %%
df
# Out:
#    A col   B col
# 0       1      20
# 1       2      19
# 2       3      18
# 3       4      17
# 4       5      16

# %%
df.columns=['aa_col','bb_col']

# %%
df
# Out:
#    aa_col  bb_col
# 0       1      20
# 1       2      19
# 2       3      18
# 3       4      17
# 4       5      16

# %%
# to replace any character, string, lateral
df.columns=df.columns.str.replace('_',' ')

# %%
df
# Out:
#    aa col  bb col
# 0       1      20
# 1       2      19
# 2       3      18
# 3       4      17
# 4       5      16

# %%
# adding prefix
df.add_prefix('UHS_')
# Out:
#    UHS_aa col  UHS_bb col
# 0           1          20
# 1           2          19
# 2           3          18
# 3           4          17
# 4           5          16

# %%
# adding suffix
df.add_suffix('_UHS')
# Out:
#    aa col_UHS  bb col_UHS
# 0           1          20
# 1           2          19
# 2           3          18
# 3           4          17
# 4           5          16

# %% [markdown]
# # 4 using template data

# %%
import pandas as pd
import numpy as np
import seaborn as sns

kashti = sns.load_dataset('titanic')
kashti.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
#  summary
kashti.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
# cloumns names
kashti.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
# saving a template dataset

kashti.to_csv('kashti.csv')

# %%
# saving to excel
kashti.to_excel('kashti.xlsx')

# %%
# viewing csv file
kashti=pd.read_csv('kashti.csv')
kashti
# Out:
#      Unnamed: 0  survived  pclass     sex   age  sibsp  parch     fare  \
# 0             0         0       3    male  22.0      1      0   7.2500
# 1             1         1       1  female  38.0      1      0  71.2833
# 2             2         1       3  female  26.0      0      0   7.9250
# 3             3         1       1  female  35.0      1      0  53.1000
# 4             4         0       3    male  35.0      0      0   8.0500
# ..          ...       ...     ...     ...   ...    ...    ...      ...
# 886         886         0       2    male  27.0      0      0  13.0000
# 887         887         1       1  female  19.0      0      0  30.0000
# 888         888         0       3  female   NaN      1      2  23.4500
# 889         889         1       1    male  26.0      0      0  30.0000
# 890         890         0       3    male  32.0      0      0   7.7500
#
#     embarked   class    who  adult_male deck  embark_town alive  alone
# 0          S   Third    man        True  NaN  Southampton    no  False
# 1          C   First  woman       False    C    Cherbourg   yes  False
# 2          S   Third  woman       False  NaN  Southampton   yes   True
# 3          S   First  woman       False    C  Southampton   yes  False
# 4          S   Third    man        True  NaN  Southampton    no   True
# ..       ...     ...    ...         ...  ...          ...   ...    ...
# 886        S  Second    man        True  NaN  Southampton    no   True
# 887        S   First  woman       False    B  Southampton   yes   True
# 888        S   Third  woman       False  NaN  Southampton    no  False
# 889        C   First    man        True    C    Cherbourg   yes   True
# 890        Q   Third    man        True  NaN   Queenstown    no   True
#
# [891 rows x 16 columns]

# %%
# reading excel file
kashti=pd.read_excel('kashti.xlsx')
kashti
# Out:
#      Unnamed: 0  survived  pclass     sex   age  sibsp  parch     fare  \
# 0             0         0       3    male  22.0      1      0   7.2500
# 1             1         1       1  female  38.0      1      0  71.2833
# 2             2         1       3  female  26.0      0      0   7.9250
# 3             3         1       1  female  35.0      1      0  53.1000
# 4             4         0       3    male  35.0      0      0   8.0500
# ..          ...       ...     ...     ...   ...    ...    ...      ...
# 886         886         0       2    male  27.0      0      0  13.0000
# 887         887         1       1  female  19.0      0      0  30.0000
# 888         888         0       3  female   NaN      1      2  23.4500
# 889         889         1       1    male  26.0      0      0  30.0000
# 890         890         0       3    male  32.0      0      0   7.7500
#
#     embarked   class    who  adult_male deck  embark_town alive  alone
# 0          S   Third    man        True  NaN  Southampton    no  False
# 1          C   First  woman       False    C    Cherbourg   yes  False
# 2          S   Third  woman       False  NaN  Southampton   yes   True
# 3          S   First  woman       False    C  Southampton   yes  False
# 4          S   Third    man        True  NaN  Southampton    no   True
# ..       ...     ...    ...         ...  ...          ...   ...    ...
# 886        S  Second    man        True  NaN  Southampton    no   True
# 887        S   First  woman       False    B  Southampton   yes   True
# 888        S   Third  woman       False  NaN  Southampton    no  False
# 889        C   First    man        True    C    Cherbourg   yes   True
# 890        Q   Third    man        True  NaN   Queenstown    no   True
#
# [891 rows x 16 columns]

# %%
# to text file
kashti.to_csv('kashti.txt',sep='\t')

# %%
#  reading text file
kashti=pd.read_csv('kashti.txt',sep='\t')
kashti
# Out:
#      Unnamed: 0.1  Unnamed: 0  survived  pclass     sex   age  sibsp  parch  \
# 0               0           0         0       3    male  22.0      1      0
# 1               1           1         1       1  female  38.0      1      0
# 2               2           2         1       3  female  26.0      0      0
# 3               3           3         1       1  female  35.0      1      0
# 4               4           4         0       3    male  35.0      0      0
# ..            ...         ...       ...     ...     ...   ...    ...    ...
# 886           886         886         0       2    male  27.0      0      0
# 887           887         887         1       1  female  19.0      0      0
# 888           888         888         0       3  female   NaN      1      2
# 889           889         889         1       1    male  26.0      0      0
# 890           890         890         0       3    male  32.0      0      0
#
#         fare embarked   class    who  adult_male deck  embark_town alive  \
# 0     7.2500        S   Third    man        True  NaN  Southampton    no
# 1    71.2833        C   First  woman       False    C    Cherbourg   yes
# 2     7.9250        S   Third  woman       False  NaN  Southampton   yes
# 3    53.1000        S   First  woman       False    C  Southampton   yes
# 4     8.0500        S   Third    man        True  NaN  Southampton    no
# ..       ...      ...     ...    ...         ...  ...          ...   ...
# 886  13.0000        S  Second    man        True  NaN  Southampton    no
# 887  30.0000        S   First  woman       False    B  Southampton   yes
# 888  23.4500        S   Third  woman       False  NaN  Southampton    no
# 889  30.0000        C   First    man        True    C    Cherbourg   yes
# 890   7.7500        Q   Third    man        True  NaN   Queenstown    no
#
#      alone
# 0    False
# 1    False
# 2     True
# 3    False
# 4     True
# ..     ...
# 886   True
# 887   True
# 888  False
# 889   True
# 890   True
#
# [891 rows x 17 columns]

# %% [markdown]
# # 5 using your own data

# %%
import pandas as pd
df = pd.read_csv('database.csv')
df
# Out:
#              Date      Time  Latitude  Longitude        Type   Depth  \
# 0      01/02/1965  13:44:18   19.2460   145.6160  Earthquake  131.60
# 1      01/04/1965  11:29:49    1.8630   127.3520  Earthquake   80.00
# 2      01/05/1965  18:05:58  -20.5790  -173.9720  Earthquake   20.00
# 3      01/08/1965  18:49:43  -59.0760   -23.5570  Earthquake   15.00
# 4      01/09/1965  13:32:50   11.9380   126.4270  Earthquake   15.00
# ...           ...       ...       ...        ...         ...     ...
# 23407  12/28/2016  08:22:12   38.3917  -118.8941  Earthquake   12.30
# 23408  12/28/2016  09:13:47   38.3777  -118.8957  Earthquake    8.80
# 23409  12/28/2016  12:38:51   36.9179   140.4262  Earthquake   10.00
# 23410  12/29/2016  22:30:19   -9.0283   118.6639  Earthquake   79.00
# 23411  12/30/2016  20:08:28   37.3973   141.4103  Earthquake   11.94
#
#        Depth Error  Depth Seismic Stations  Magnitude Magnitude Type  ...  \
# 0              NaN                     NaN        6.0             MW  ...
# 1              NaN                     NaN        5.8             MW  ...
# 2              NaN                     NaN        6.2             MW  ...
# 3              NaN                     NaN        5.8             MW  ...
# 4              NaN                     NaN        5.8             MW  ...
# ...            ...                     ...        ...            ...  ...
# 23407          1.2                    40.0        5.6             ML  ...
# 23408          2.0                    33.0        5.5             ML  ...
# 23409          1.8                     NaN        5.9            MWW  ...
# 23410          1.8                     NaN        6.3            MWW  ...
# 23411          2.2                     NaN        5.5             MB  ...
#
#        Magnitude Seismic Stations  Azimuthal Gap  Horizontal Distance  \
# 0                             NaN            NaN                  NaN
# 1                             NaN            NaN                  NaN
# 2                             NaN            NaN                  NaN
# 3                             NaN            NaN                  NaN
# 4                             NaN            NaN                  NaN
# ...                           ...            ...                  ...
# 23407                        18.0          42.47                0.120
# 23408                        18.0          48.58                0.129
# 23409                         NaN          91.00                0.992
# 23410                         NaN          26.00                3.553
# 23411                       428.0          97.00                0.681
#
#        Horizontal Error  Root Mean Square            ID  Source  \
# 0                   NaN               NaN  ISCGEM860706  ISCGEM
# 1                   NaN               NaN  ISCGEM860737  ISCGEM
# 2                   NaN               NaN  ISCGEM860762  ISCGEM
# 3                   NaN               NaN  ISCGEM860856  ISCGEM
# 4                   NaN               NaN  ISCGEM860890  ISCGEM
# ...                 ...               ...           ...     ...
# 23407               NaN            0.1898    NN00570710      NN
# 23408               NaN            0.2187    NN00570744      NN
# 23409               4.8            1.5200    US10007NAF      US
# 23410               6.0            1.4300    US10007NL0      US
# 23411               4.5            0.9100    US10007NTD      US
#
#       Location Source Magnitude Source     Status
# 0              ISCGEM           ISCGEM  Automatic
# 1              ISCGEM           ISCGEM  Automatic
# 2              ISCGEM           ISCGEM  Automatic
# 3              ISCGEM           ISCGEM  Automatic
# 4              ISCGEM           ISCGEM  Automatic
# ...               ...              ...        ...
# 23407              NN               NN   Reviewed
# 23408              NN               NN   Reviewed
# 23409              US               US   Reviewed
# 23410              US               US   Reviewed
# 23411              US               US   Reviewed
#
# [23412 rows x 21 columns]

# %%
df.head()
# Out:
#          Date      Time  Latitude  Longitude        Type  Depth  Depth Error  \
# 0  01/02/1965  13:44:18    19.246    145.616  Earthquake  131.6          NaN
# 1  01/04/1965  11:29:49     1.863    127.352  Earthquake   80.0          NaN
# 2  01/05/1965  18:05:58   -20.579   -173.972  Earthquake   20.0          NaN
# 3  01/08/1965  18:49:43   -59.076    -23.557  Earthquake   15.0          NaN
# 4  01/09/1965  13:32:50    11.938    126.427  Earthquake   15.0          NaN
#
#    Depth Seismic Stations  Magnitude Magnitude Type  ...  \
# 0                     NaN        6.0             MW  ...
# 1                     NaN        5.8             MW  ...
# 2                     NaN        6.2             MW  ...
# 3                     NaN        5.8             MW  ...
# 4                     NaN        5.8             MW  ...
#
#    Magnitude Seismic Stations  Azimuthal Gap  Horizontal Distance  \
# 0                         NaN            NaN                  NaN
# 1                         NaN            NaN                  NaN
# 2                         NaN            NaN                  NaN
# 3                         NaN            NaN                  NaN
# 4                         NaN            NaN                  NaN
#
#    Horizontal Error  Root Mean Square            ID  Source Location Source  \
# 0               NaN               NaN  ISCGEM860706  ISCGEM          ISCGEM
# 1               NaN               NaN  ISCGEM860737  ISCGEM          ISCGEM
# 2               NaN               NaN  ISCGEM860762  ISCGEM          ISCGEM
# 3               NaN               NaN  ISCGEM860856  ISCGEM          ISCGEM
# 4               NaN               NaN  ISCGEM860890  ISCGEM          ISCGEM
#
#   Magnitude Source     Status
# 0           ISCGEM  Automatic
# 1           ISCGEM  Automatic
# 2           ISCGEM  Automatic
# 3           ISCGEM  Automatic
# 4           ISCGEM  Automatic
#
# [5 rows x 21 columns]

# %% [markdown]
# # 6 reverse row order

# %%
import pandas as pd
import seaborn as sns

df=sns.load_dataset('titanic')
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True

# %%
# to check in descending order
df.loc[::-1].head()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 890         0       3    male  32.0      0      0   7.75        Q   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 887         1       1  female  19.0      0      0  30.00        S   First
# 886         0       2    male  27.0      0      0  13.00        S  Second
#
#        who  adult_male deck  embark_town alive  alone
# 890    man        True  NaN   Queenstown    no   True
# 889    man        True    C    Cherbourg   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 887  woman       False    B  Southampton   yes   True
# 886    man        True  NaN  Southampton    no   True

# %%
df.loc[::-1].reset_index(drop=True).head()
# Out:
#    survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 0         0       3    male  32.0      0      0   7.75        Q   Third
# 1         1       1    male  26.0      0      0  30.00        C   First
# 2         0       3  female   NaN      1      2  23.45        S   Third
# 3         1       1  female  19.0      0      0  30.00        S   First
# 4         0       2    male  27.0      0      0  13.00        S  Second
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN   Queenstown    no   True
# 1    man        True    C    Cherbourg   yes   True
# 2  woman       False  NaN  Southampton    no  False
# 3  woman       False    B  Southampton   yes   True
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# # 7- reverse colun order

# %%
df.loc[:,::-1].head()
# Out:
#    alone alive  embark_town deck  adult_male    who  class embarked     fare  \
# 0  False    no  Southampton  NaN        True    man  Third        S   7.2500
# 1  False   yes    Cherbourg    C       False  woman  First        C  71.2833
# 2   True   yes  Southampton  NaN       False  woman  Third        S   7.9250
# 3  False   yes  Southampton    C       False  woman  First        S  53.1000
# 4   True    no  Southampton  NaN        True    man  Third        S   8.0500
#
#    parch  sibsp   age     sex  pclass  survived
# 0      0      1  22.0    male       3         0
# 1      0      1  38.0  female       1         1
# 2      0      0  26.0  female       3         1
# 3      0      1  35.0  female       1         1
# 4      0      0  35.0    male       3         0

# %% [markdown]
# # 8- select a cloumn by a data type

# %%
df.dtypes
# Out:
# survived          int64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %%
# only select those having numeric datatype

df.select_dtypes(include=['number']).head()
# Out:
#    survived  pclass   age  sibsp  parch     fare
# 0         0       3  22.0      1      0   7.2500
# 1         1       1  38.0      1      0  71.2833
# 2         1       3  26.0      0      0   7.9250
# 3         1       1  35.0      1      0  53.1000
# 4         0       3  35.0      0      0   8.0500

# %%
#  those with float
df.select_dtypes(include=['float']).head()
# Out:
#     age     fare
# 0  22.0   7.2500
# 1  38.0  71.2833
# 2  26.0   7.9250
# 3  35.0  53.1000
# 4  35.0   8.0500

# %%
#  those with object
df.select_dtypes(include=['object']).head()
# Out:
#       sex embarked    who  embark_town alive
# 0    male        S    man  Southampton    no
# 1  female        C  woman    Cherbourg   yes
# 2  female        S  woman  Southampton   yes
# 3  female        S  woman  Southampton   yes
# 4    male        S    man  Southampton    no

# %%
#  those with multiple datatypes
df.select_dtypes(include=['float','number','object']).head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked    who  \
# 0         0       3    male  22.0      1      0   7.2500        S    man
# 1         1       1  female  38.0      1      0  71.2833        C  woman
# 2         1       3  female  26.0      0      0   7.9250        S  woman
# 3         1       1  female  35.0      1      0  53.1000        S  woman
# 4         0       3    male  35.0      0      0   8.0500        S    man
#
#    embark_town alive
# 0  Southampton    no
# 1    Cherbourg   yes
# 2  Southampton   yes
# 3  Southampton   yes
# 4  Southampton    no

# %%
df.select_dtypes(exclude=['number']).head()
# Out:
#       sex embarked  class    who  adult_male deck  embark_town alive  alone
# 0    male        S  Third    man        True  NaN  Southampton    no  False
# 1  female        C  First  woman       False    C    Cherbourg   yes  False
# 2  female        S  Third  woman       False  NaN  Southampton   yes   True
# 3  female        S  First  woman       False    C  Southampton   yes  False
# 4    male        S  Third    man        True  NaN  Southampton    no   True

# %% [markdown]
# # 9- convert numbers into strings

# %%
# creating a dataframe
df = pd.DataFrame({'col a' : ['1','2','3','4','5'],
                   'col b':['6','7','8','9','10']})
df
# Out:
#   col a col b
# 0     1     6
# 1     2     7
# 2     3     8
# 3     4     9
# 4     5    10

# %%
df.dtypes
# Out:
# col a    object
# col b    object
# dtype: object

# %%
# changing datatype to numeric
pd.to_numeric(df['col a'],errors='coerce')
df.dtypes
# Out:
# col a    object
# col b    object
# dtype: object

# %%
#  changing type object to int
df=df.astype({'col a':'int','col b':'object'})

# %%
df.dtypes
# Out:
# col a     int32
# col b    object
# dtype: object

# %%
# changing datatype to numeric
df=pd.to_numeric(df['col b'],errors='coerce')

# %% [markdown]
# # 10- reduce dataframe size

# %%
df=sns.load_dataset('titanic')

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
#  checking the memory usage by this dataset in our computer
df.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 313.7 KB

# %%
# reducing the size by taking a fraction of whole dataset
df.sample(frac=0.1).shape
# Out:
# (89, 15)

# %%
#  taking 0.5 fraction of whole dataset
df.sample(frac=0.5).shape
# Out:
# (446, 15)

# %% [markdown]
# # 11- copy data from clipboard

# %%
# dataset download
import seaborn as sns
import pandas as pd

df=sns.load_dataset('titanic')
df.to_excel('kashti.xlsx')

# %%
# read clipboard in python
df=pd.read_clipboard()
df
# Out:
# Empty DataFrame
# Columns: [https://workupload.com/file/yTDzEqdkPwG]
# Index: []

# %% [markdown]
# # 12 - split data sets in two frames

# %%
# dataset download
import seaborn as sns
import pandas as pd

df=sns.load_dataset('titanic')
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
len(df)
# Out:
# 891

# %%
df.shape
# Out:
# (891, 15)

# %%
# we have one sample of data set
from random import random
kashti_1 = df.sample(frac=0.5,random_state=1)
kashti_1.shape
# Out:
# (446, 15)

# %%
#  then we just dropped taken dataset from whole dataset
kashti_2= df.drop(kashti_1.index)
kashti_2.shape
# Out:
# (445, 15)

# %%
kashti_1.head()
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 862         1       1  female  48.0      0      0  25.9292        S   First
# 223         0       3    male   NaN      0      0   7.8958        S   Third
# 84          1       2  female  17.0      0      0  10.5000        S  Second
# 680         0       3  female   NaN      0      0   8.1375        Q   Third
# 535         1       2  female   7.0      0      2  26.2500        S  Second
#
#        who  adult_male deck  embark_town alive  alone
# 862  woman       False    D  Southampton   yes   True
# 223    man        True  NaN  Southampton    no   True
# 84   woman       False  NaN  Southampton   yes   True
# 680  woman       False  NaN   Queenstown    no   True
# 535  child       False  NaN  Southampton   yes  False

# %%
kashti_2.head()
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# 15         1       2  female  55.0      0      0  16.0000        S  Second
# 18         0       3  female  31.0      1      0  18.0000        S   Third
#
#       who  adult_male deck  embark_town alive  alone
# 1   woman       False    C    Cherbourg   yes  False
# 7   child       False  NaN  Southampton    no  False
# 10  child       False    G  Southampton   yes  False
# 15  woman       False  NaN  Southampton   yes   True
# 18  woman       False  NaN  Southampton    no  False

# %%
df.shape
# Out:
# (891, 15)

# %%
len(kashti_1) + len(kashti_2)
# Out:
# 891

# %% [markdown]
# # 13 - joining dataset into one dataframe

# %%
df1=kashti_1.append(kashti_2)
df1.shape
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_5768\805721718.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df1=kashti_1.append(kashti_2)
# (891, 15)

# %% [markdown]
# # 14 - filtering a data set

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
df.sex.unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
df[df.sex=="male"]
# Out:
#      survived  pclass   sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3  male  22.0      1      0   7.2500        S   Third
# 4           0       3  male  35.0      0      0   8.0500        S   Third
# 5           0       3  male   NaN      0      0   8.4583        Q   Third
# 6           0       1  male  54.0      0      0  51.8625        S   First
# 7           0       3  male   2.0      3      1  21.0750        S   Third
# ..        ...     ...   ...   ...    ...    ...      ...      ...     ...
# 883         0       2  male  28.0      0      0  10.5000        S  Second
# 884         0       3  male  25.0      0      0   7.0500        S   Third
# 886         0       2  male  27.0      0      0  13.0000        S  Second
# 889         1       1  male  26.0      0      0  30.0000        C   First
# 890         0       3  male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 4      man        True  NaN  Southampton    no   True
# 5      man        True  NaN   Queenstown    no   True
# 6      man        True    E  Southampton    no   True
# 7    child       False  NaN  Southampton    no  False
# ..     ...         ...  ...          ...   ...    ...
# 883    man        True  NaN  Southampton    no   True
# 884    man        True  NaN  Southampton    no   True
# 886    man        True  NaN  Southampton    no   True
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [577 rows x 15 columns]

# %%
df[df.sex=="female"]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 8           1       3  female  27.0      0      2  11.1333        S   Third
# 9           1       2  female  14.0      1      0  30.0708        C  Second
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 880         1       2  female  25.0      0      1  26.0000        S  Second
# 882         0       3  female  22.0      0      0  10.5167        S   Third
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
#
#        who  adult_male deck  embark_town alive  alone
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 8    woman       False  NaN  Southampton   yes  False
# 9    child       False  NaN    Cherbourg   yes  False
# ..     ...         ...  ...          ...   ...    ...
# 880  woman       False  NaN  Southampton   yes  False
# 882  woman       False  NaN  Southampton    no   True
# 885  woman       False  NaN   Queenstown    no  False
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
#
# [314 rows x 15 columns]

# %%
df.age.unique()
# Out:
# array([22.  , 38.  , 26.  , 35.  ,   nan, 54.  ,  2.  , 27.  , 14.  ,
#         4.  , 58.  , 20.  , 39.  , 55.  , 31.  , 34.  , 15.  , 28.  ,
#         8.  , 19.  , 40.  , 66.  , 42.  , 21.  , 18.  ,  3.  ,  7.  ,
#        49.  , 29.  , 65.  , 28.5 ,  5.  , 11.  , 45.  , 17.  , 32.  ,
#        16.  , 25.  ,  0.83, 30.  , 33.  , 23.  , 24.  , 46.  , 59.  ,
#        71.  , 37.  , 47.  , 14.5 , 70.5 , 32.5 , 12.  ,  9.  , 36.5 ,
#        51.  , 55.5 , 40.5 , 44.  ,  1.  , 61.  , 56.  , 50.  , 36.  ,
#        45.5 , 20.5 , 62.  , 41.  , 52.  , 63.  , 23.5 ,  0.92, 43.  ,
#        60.  , 10.  , 64.  , 13.  , 48.  ,  0.75, 53.  , 57.  , 80.  ,
#        70.  , 24.5 ,  6.  ,  0.67, 30.5 ,  0.42, 34.5 , 74.  ])

# %%
df.embarked.unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
df[(df.embarked=="S")].shape
# Out:
# (644, 15)

# %%
df[((df.embark_town=="Southampton") |
    (df.embark_town=="Queenstown")) & 
    (df.sex=="female")]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 8           1       3  female  27.0      0      2  11.1333        S   Third
# 10          1       3  female   4.0      1      1  16.7000        S   Third
# 11          1       1  female  58.0      0      0  26.5500        S   First
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 880         1       2  female  25.0      0      1  26.0000        S  Second
# 882         0       3  female  22.0      0      0  10.5167        S   Third
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
#
#        who  adult_male deck  embark_town alive  alone
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 8    woman       False  NaN  Southampton   yes  False
# 10   child       False    G  Southampton   yes  False
# 11   woman       False    C  Southampton   yes   True
# ..     ...         ...  ...          ...   ...    ...
# 880  woman       False  NaN  Southampton   yes  False
# 882  woman       False  NaN  Southampton    no   True
# 885  woman       False  NaN   Queenstown    no  False
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
#
# [239 rows x 15 columns]

# %%
df[df.embark_town.isin(['Queenstown','Southampton'])].head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
# 5         0       3    male   NaN      0      0   8.4583        Q  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True
# 5    man        True  NaN   Queenstown    no   True

# %%
df[df.age > 30].shape
# df[df.age < 30].shape
# Out:
# (305, 15)

# %% [markdown]
# # 15 filtering by large categories

# %%
df.embark_town.value_counts()
# Out:
# Southampton    644
# Cherbourg      168
# Queenstown      77
# Name: embark_town, dtype: int64

# %%
df.sex.value_counts()
# Out:
# male      577
# female    314
# Name: sex, dtype: int64

# %%
df.age.value_counts().nlargest(5)
# Out:
# 24.0    30
# 22.0    27
# 18.0    26
# 19.0    25
# 28.0    25
# Name: age, dtype: int64

# %%
counts= df.embark_town.value_counts()
counts.nlargest(3)
# Out:
# Southampton    644
# Cherbourg      168
# Queenstown      77
# Name: embark_town, dtype: int64

# %%
counts= df.who.value_counts()
counts.nlargest(3)
# Out:
# man      537
# woman    271
# child     83
# Name: who, dtype: int64

# %%
df[df.who.isin(counts.nlargest(1).index)].head()
# Out:
#     survived  pclass   sex   age  sibsp  parch     fare embarked  class  who  \
# 0          0       3  male  22.0      1      0   7.2500        S  Third  man
# 4          0       3  male  35.0      0      0   8.0500        S  Third  man
# 5          0       3  male   NaN      0      0   8.4583        Q  Third  man
# 6          0       1  male  54.0      0      0  51.8625        S  First  man
# 12         0       3  male  20.0      0      0   8.0500        S  Third  man
#
#     adult_male deck  embark_town alive  alone
# 0         True  NaN  Southampton    no  False
# 4         True  NaN  Southampton    no   True
# 5         True  NaN   Queenstown    no   True
# 6         True    E  Southampton    no   True
# 12        True  NaN  Southampton    no   True

# %% [markdown]
# # 16 - splitting a string into multiple cloumns

# %%
#  import libraries
import pandas as pd

#  read dataset
df=pd.DataFrame({'Name':['Uzair Hussain','Mirza Abbas','Abdul Lahad','Razi Khanzada'],
                        'Location':['Karachi Pakistan','Nawabshah Pakistan','Dadu Pakistan','Hyderabad Pakistan']})
df
# Out:
#             Name            Location
# 0  Uzair Hussain    Karachi Pakistan
# 1    Mirza Abbas  Nawabshah Pakistan
# 2    Abdul Lahad       Dadu Pakistan
# 3  Razi Khanzada  Hyderabad Pakistan

# %%
# splitting into two columns
df[["first name","last name"]] = df.Name.str.split(' ',expand=True)

# %%
# printing those two columns as well
df
# Out:
#             Name            Location first name last name
# 0  Uzair Hussain    Karachi Pakistan      Uzair   Hussain
# 1    Mirza Abbas  Nawabshah Pakistan      Mirza     Abbas
# 2    Abdul Lahad       Dadu Pakistan      Abdul     Lahad
# 3  Razi Khanzada  Hyderabad Pakistan       Razi  Khanzada

# %%
# splitting location into two columns
df[["city","country"]] = df.Location.str.split(' ',expand=True)

# %%
# printing those two columns as well
df
# Out:
#             Name            Location first name last name       city   country
# 0  Uzair Hussain    Karachi Pakistan      Uzair   Hussain    Karachi  Pakistan
# 1    Mirza Abbas  Nawabshah Pakistan      Mirza     Abbas  Nawabshah  Pakistan
# 2    Abdul Lahad       Dadu Pakistan      Abdul     Lahad       Dadu  Pakistan
# 3  Razi Khanzada  Hyderabad Pakistan       Razi  Khanzada  Hyderabad  Pakistan

# %%
# refined dataset
df = df[["first name","last name","city","country"]]
df
# Out:
#   first name last name       city   country
# 0      Uzair   Hussain    Karachi  Pakistan
# 1      Mirza     Abbas  Nawabshah  Pakistan
# 2      Abdul     Lahad       Dadu  Pakistan
# 3       Razi  Khanzada  Hyderabad  Pakistan

# %% [markdown]
# # 17 - Aggregate by multiple groups/functions

# %%
# import libraries
import pandas as pd
import numpy as np
import seaborn as sns

# checking dataset available in seaborn library
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
# import dataset
df=sns.load_dataset('titanic')
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.groupby('who').count()
# Out:
#        survived  pclass  sex  age  sibsp  parch  fare  embarked  class  \
# who
# child        83      83   83   83     83     83    83        83     83
# man         537     537  537  413    537    537   537       537    537
# woman       271     271  271  218    271    271   271       269    271
#
#        adult_male  deck  embark_town  alive  alone
# who
# child          83    13           83     83     83
# man           537    99          537    537    537
# woman         271    91          269    271    271

# %%
df.groupby('who').sum()
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_5768\2979829937.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('who').sum()
#        survived  pclass       age  sibsp  parch        fare  adult_male  alone
# who
# child        49     218    528.67    144    105   2721.2210           0      6
# man          88    1274  13700.50    159     82  13352.0656         537    410
# woman       205     565   6976.00    163    153  12620.6627           0    121

# %%
len(df.groupby('sex'))
# Out:
# 2

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.groupby(['sex','pclass','who']).count()
# Out:
#                      survived  age  sibsp  parch  fare  embarked  class  \
# sex    pclass who
# female 1      child         3    3      3      3     3         3      3
#               woman        91   82     91     91    91        89     91
#        2      child        10   10     10     10    10        10     10
#               woman        66   64     66     66    66        66     66
#        3      child        30   30     30     30    30        30     30
#               woman       114   72    114    114   114       114    114
# male   1      child         3    3      3      3     3         3      3
#               man         119   98    119    119   119       119    119
#        2      child         9    9      9      9     9         9      9
#               man          99   90     99     99    99        99     99
#        3      child        28   28     28     28    28        28     28
#               man         319  225    319    319   319       319    319
#
#                      adult_male  deck  embark_town  alive  alone
# sex    pclass who
# female 1      child           3     3            3      3      3
#               woman          91    78           89     91     91
#        2      child          10     1           10     10     10
#               woman          66     9           66     66     66
#        3      child          30     2           30     30     30
#               woman         114     4          114    114    114
# male   1      child           3     3            3      3      3
#               man           119    91          119    119    119
#        2      child           9     3            9      9      9
#               man            99     3           99     99     99
#        3      child          28     1           28     28     28
#               man           319     5          319    319    319

# %%
df.groupby(['sex','pclass','embarked']).count()
# Out:
#                         survived  age  sibsp  parch  fare  class  who  \
# sex    pclass embarked
# female 1      C               43   38     43     43    43     43   43
#               Q                1    1      1      1     1      1    1
#               S               48   44     48     48    48     48   48
#        2      C                7    7      7      7     7      7    7
#               Q                2    1      2      2     2      2    2
#               S               67   66     67     67    67     67   67
#        3      C               23   16     23     23    23     23   23
#               Q               33   10     33     33    33     33   33
#               S               88   76     88     88    88     88   88
# male   1      C               42   36     42     42    42     42   42
#               Q                1    1      1      1     1      1    1
#               S               79   64     79     79    79     79   79
#        2      C               10    8     10     10    10     10   10
#               Q                1    1      1      1     1      1    1
#               S               97   90     97     97    97     97   97
#        3      C               43   25     43     43    43     43   43
#               Q               39   14     39     39    39     39   39
#               S              265  214    265    265   265    265  265
#
#                         adult_male  deck  embark_town  alive  alone
# sex    pclass embarked
# female 1      C                 43    35           43     43     43
#               Q                  1     1            1      1      1
#               S                 48    43           48     48     48
#        2      C                  7     1            7      7      7
#               Q                  2     1            2      2      2
#               S                 67     8           67     67     67
#        3      C                 23     1           23     23     23
#               Q                 33     0           33     33     33
#               S                 88     5           88     88     88
# male   1      C                 42    31           42     42     42
#               Q                  1     1            1      1      1
#               S                 79    62           79     79     79
#        2      C                 10     1           10     10     10
#               Q                  1     0            1      1      1
#               S                 97     5           97     97     97
#        3      C                 43     0           43     43     43
#               Q                 39     1           39     39     39
#               S                265     5          265    265    265

# %%
df.groupby(['sex','pclass','embark_town']).count()
# Out:
#                            survived  age  sibsp  parch  fare  embarked  class  \
# sex    pclass embark_town
# female 1      Cherbourg          43   38     43     43    43        43     43
#               Queenstown          1    1      1      1     1         1      1
#               Southampton        48   44     48     48    48        48     48
#        2      Cherbourg           7    7      7      7     7         7      7
#               Queenstown          2    1      2      2     2         2      2
#               Southampton        67   66     67     67    67        67     67
#        3      Cherbourg          23   16     23     23    23        23     23
#               Queenstown         33   10     33     33    33        33     33
#               Southampton        88   76     88     88    88        88     88
# male   1      Cherbourg          42   36     42     42    42        42     42
#               Queenstown          1    1      1      1     1         1      1
#               Southampton        79   64     79     79    79        79     79
#        2      Cherbourg          10    8     10     10    10        10     10
#               Queenstown          1    1      1      1     1         1      1
#               Southampton        97   90     97     97    97        97     97
#        3      Cherbourg          43   25     43     43    43        43     43
#               Queenstown         39   14     39     39    39        39     39
#               Southampton       265  214    265    265   265       265    265
#
#                            who  adult_male  deck  alive  alone
# sex    pclass embark_town
# female 1      Cherbourg     43          43    35     43     43
#               Queenstown     1           1     1      1      1
#               Southampton   48          48    43     48     48
#        2      Cherbourg      7           7     1      7      7
#               Queenstown     2           2     1      2      2
#               Southampton   67          67     8     67     67
#        3      Cherbourg     23          23     1     23     23
#               Queenstown    33          33     0     33     33
#               Southampton   88          88     5     88     88
# male   1      Cherbourg     42          42    31     42     42
#               Queenstown     1           1     1      1      1
#               Southampton   79          79    62     79     79
#        2      Cherbourg     10          10     1     10     10
#               Queenstown     1           1     0      1      1
#               Southampton   97          97     5     97     97
#        3      Cherbourg     43          43     0     43     43
#               Queenstown    39          39     1     39     39
#               Southampton  265         265     5    265    265

# %% [markdown]
# # 18 - select specific rows and columns

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df[['sex','class','age','parch']]
# Out:
#         sex   class   age  parch
# 0      male   Third  22.0      0
# 1    female   First  38.0      0
# 2    female   Third  26.0      0
# 3    female   First  35.0      0
# 4      male   Third  35.0      0
# ..      ...     ...   ...    ...
# 886    male  Second  27.0      0
# 887  female   First  19.0      0
# 888  female   Third   NaN      2
# 889    male   First  26.0      0
# 890    male   Third  32.0      0
#
# [891 rows x 4 columns]

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df[['sex','class']]
# Out:
#         sex   class
# 0      male   Third
# 1    female   First
# 2    female   Third
# 3    female   First
# 4      male   Third
# ..      ...     ...
# 886    male  Second
# 887  female   First
# 888  female   Third
# 889    male   First
# 890    male   Third
#
# [891 rows x 2 columns]

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
# df.describe().loc[['min','25%','50%','75%','max']]
# or
df.describe().loc['min':'max','survived':'age']
# Out:
#      survived  pclass     age
# min       0.0     1.0   0.420
# 25%       0.0     2.0  20.125
# 50%       0.0     3.0  28.000
# 75%       1.0     3.0  38.000
# max       1.0     3.0  80.000

# %% [markdown]
# # 19- Reshape multiindex series

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.survived.mean()
# Out:
# 0.3838383838383838

# %%
df.groupby(['sex','class']).survived.mean()
# Out:
# sex     class
# female  First     0.968085
#         Second    0.921053
#         Third     0.500000
# male    First     0.368852
#         Second    0.157407
#         Third     0.135447
# Name: survived, dtype: float64

# %%
df.groupby(['sex','class']).survived.mean().unstack()
# Out:
# class      First    Second     Third
# sex
# female  0.968085  0.921053  0.500000
# male    0.368852  0.157407  0.135447

# %% [markdown]
# # 20- Continous to categorical data conversion

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.age.head()
# Out:
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# Name: age, dtype: float64

# %%
# pd.cut(df.age,bins=[0,18,25,99],labels=['child','young_adult','adult']).head()
df['new_age'] = pd.cut(df.age,bins=[0,18,25,99],labels=['child','young_adult','adult']).head()
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone      new_age
# 0    man        True  NaN  Southampton    no  False  young_adult
# 1  woman       False    C    Cherbourg   yes  False        adult
# 2  woman       False  NaN  Southampton   yes   True        adult
# 3  woman       False    C  Southampton   yes  False        adult
# 4    man        True  NaN  Southampton    no   True        adult

# %% [markdown]
# # 21- Convert one set of values into another one

# %%
df.sex.head()
# Out:
# 0      male
# 1    female
# 2    female
# 3    female
# 4      male
# Name: sex, dtype: object

# %%
df.sex.map({'male':0,'female':1})
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    1
# 889    0
# 890    0
# Name: sex, Length: 891, dtype: int64

# %%
df['sex_number']=df.sex.map({'male':0,'female':1})

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone      new_age  sex_number
# 0      man        True  NaN  Southampton    no  False  young_adult           0
# 1    woman       False    C    Cherbourg   yes  False        adult           1
# 2    woman       False  NaN  Southampton   yes   True        adult           1
# 3    woman       False    C  Southampton   yes  False        adult           1
# 4      man        True  NaN  Southampton    no   True        adult           0
# ..     ...         ...  ...          ...   ...    ...          ...         ...
# 886    man        True  NaN  Southampton    no   True          NaN           0
# 887  woman       False    B  Southampton   yes   True          NaN           1
# 888  woman       False  NaN  Southampton    no  False          NaN           1
# 889    man        True    C    Cherbourg   yes   True          NaN           0
# 890    man        True  NaN   Queenstown    no   True          NaN           0
#
# [891 rows x 17 columns]

# %%
df.embarked.count()
# Out:
# 889

# %%
df.embarked.unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
df['embarked_number']=df.embarked.factorize()[0]

# %%
df.head(10)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0         0       3    male  22.0      1      0   7.2500        S   Third
# 1         1       1  female  38.0      1      0  71.2833        C   First
# 2         1       3  female  26.0      0      0   7.9250        S   Third
# 3         1       1  female  35.0      1      0  53.1000        S   First
# 4         0       3    male  35.0      0      0   8.0500        S   Third
# 5         0       3    male   NaN      0      0   8.4583        Q   Third
# 6         0       1    male  54.0      0      0  51.8625        S   First
# 7         0       3    male   2.0      3      1  21.0750        S   Third
# 8         1       3  female  27.0      0      2  11.1333        S   Third
# 9         1       2  female  14.0      1      0  30.0708        C  Second
#
#      who  adult_male deck  embark_town alive  alone      new_age  sex_number  \
# 0    man        True  NaN  Southampton    no  False  young_adult           0
# 1  woman       False    C    Cherbourg   yes  False        adult           1
# 2  woman       False  NaN  Southampton   yes   True        adult           1
# 3  woman       False    C  Southampton   yes  False        adult           1
# 4    man        True  NaN  Southampton    no   True        adult           0
# 5    man        True  NaN   Queenstown    no   True          NaN           0
# 6    man        True    E  Southampton    no   True          NaN           0
# 7  child       False  NaN  Southampton    no  False          NaN           0
# 8  woman       False  NaN  Southampton   yes  False          NaN           1
# 9  child       False  NaN    Cherbourg   yes  False          NaN           1
#
#    embarked_number
# 0                0
# 1                1
# 2                0
# 3                0
# 4                0
# 5                2
# 6                0
# 7                0
# 8                0
# 9                1

# %% [markdown]
# # 22- Transpose a wide dataframe

# %%
import pandas as pd
import numpy as np

# %%
#  creating a new df
df=pd.DataFrame(np.random.rand(200,25),columns=list('abcdefghijklmnopqrstuvwxy'))

# %%
df.head(10)
# Out:
#           a         b         c         d         e         f         g  \
# 0  0.177726  0.711109  0.441217  0.181235  0.001793  0.431590  0.098808
# 1  0.765965  0.216482  0.914893  0.680878  0.168962  0.722148  0.922543
# 2  0.522517  0.499451  0.531832  0.966846  0.073968  0.821580  0.501440
# 3  0.562394  0.593182  0.536041  0.693240  0.072972  0.012889  0.040213
# 4  0.663935  0.315080  0.489921  0.516416  0.766004  0.361142  0.899888
# 5  0.003607  0.329629  0.431745  0.337375  0.122291  0.321818  0.669459
# 6  0.810013  0.301737  0.224969  0.412276  0.029471  0.124840  0.796363
# 7  0.334441  0.193772  0.140057  0.118117  0.555040  0.539243  0.339119
# 8  0.947887  0.536725  0.888461  0.077678  0.124669  0.640770  0.639825
# 9  0.004411  0.613830  0.001943  0.257297  0.843885  0.900821  0.256998
#
#           h         i         j  ...         p         q         r         s  \
# 0  0.913467  0.872444  0.933141  ...  0.391519  0.237082  0.467132  0.814994
# 1  0.863134  0.039630  0.815875  ...  0.982787  0.047825  0.779094  0.470643
# 2  0.574936  0.268045  0.018462  ...  0.130431  0.308224  0.259885  0.425410
# 3  0.367654  0.652658  0.310668  ...  0.728265  0.250441  0.293370  0.358097
# 4  0.780455  0.943649  0.510060  ...  0.121279  0.357345  0.207633  0.748034
# 5  0.468435  0.174192  0.022465  ...  0.320658  0.657604  0.579347  0.522189
# 6  0.790104  0.662727  0.824716  ...  0.065234  0.946208  0.260708  0.256737
# 7  0.863968  0.109962  0.341160  ...  0.168946  0.448720  0.590739  0.622663
# 8  0.247691  0.268984  0.011177  ...  0.447841  0.102831  0.951412  0.937831
# 9  0.185038  0.734312  0.510058  ...  0.657186  0.609010  0.645400  0.876882
#
#           t         u         v         w         x         y
# 0  0.398087  0.982986  0.597374  0.980277  0.111117  0.334203
# 1  0.540588  0.264299  0.459884  0.338352  0.317195  0.091774
# 2  0.811260  0.947721  0.766467  0.998487  0.955164  0.698438
# 3  0.550060  0.976915  0.159392  0.380321  0.597407  0.241698
# 4  0.028449  0.107034  0.908567  0.258847  0.362638  0.062696
# 5  0.680815  0.999791  0.236560  0.490225  0.863405  0.225148
# 6  0.491029  0.075125  0.110299  0.827339  0.964808  0.685056
# 7  0.175417  0.592514  0.535064  0.565128  0.185678  0.374601
# 8  0.350576  0.149484  0.425604  0.502337  0.295912  0.546932
# 9  0.128230  0.838217  0.484546  0.261441  0.172007  0.683109
#
# [10 rows x 25 columns]

# %%
df.head(10).T
# Out:
#           0         1         2         3         4         5         6  \
# a  0